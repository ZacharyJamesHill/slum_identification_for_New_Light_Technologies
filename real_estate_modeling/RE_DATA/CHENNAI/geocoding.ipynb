# %%
import re
import time
import numpy as np
import pandas as pd
import googlemaps as gmaps

gmaps = gmaps.Client(key='AIzaSyAiiG2SnCVLWlg0ZA6GKXS-beHPIidYVeM')

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()

# %%
df = pd.read_csv('data.csv')
print(df.shape)
df.head(5)
# Out:
# (2406, 14)
#       price                                              title  longitude  \
# 0  ₹ 19,000  3 BHK Apartment for rent in Vijay Shanthi Apar...  12.760201
# 1   ₹ 8,500        1 BHK House for rent in Tambaram Sanatorium  13.044208
# 2  ₹ 35,000  3 BHK Builder Floor for rent in Pushpa Nagar-N...        NaN
# 3  ₹ 15,000         2 BHK House for rent in Velachery 950 sqft  12.979078
# 4  ₹ 15,000  2 BHK Apartment for rent in Arun Excello Sanka...        NaN
#
#     latitude                  floor      furnishing tenants preferred  \
# 0  80.207000                    NaN             NaN               NaN
# 1  80.200531  Ground out of 1 Floor     Unfurnished         Bachelors
# 2        NaN      2 out of 2 Floors  Semi-Furnished            Family
# 3  80.219185      1 out of 2 Floors     Unfurnished  Bachelors/Family
# 4        NaN                    NaN             NaN               NaN
#
#    bathroom facing availability car parking  balcony owner resides overlooking
# 0       NaN    NaN          NaN         NaN      NaN           NaN         NaN
# 1       1.0  South  Immediately      1 Open      NaN           NaN         NaN
# 2       3.0   East  Immediately   5 Covered      1.0  Same Premise         NaN
# 3       2.0    NaN  Immediately         NaN      1.0           NaN         NaN
# 4       NaN    NaN          NaN         NaN      NaN           NaN         NaN

# %%
def parse_address(x):
    x = re.split(' \d\d+', x)[0]
    x = re.split(' in', x)[-1]
    return x+', Hyderabad'

# %%
df['address'] = df['title'].apply(parse_address)

# %%
print(len(df), 'total rows')
unique_locs = list(set(df['address']))
print(len(unique_locs), 'unique locations')
# Out:
# 2406 total rows
# 778 unique locations

# %% [markdown]
# # Geocoding

# %%
def get_gmap_geos(locations, max_errors=10):
    geocoded = dict()
    start_time = time.perf_counter()
    errors = 0
    for iteration, location in enumerate(locations):
        try:
            geocoded[location] = gmaps.geocode(location)
            time.sleep(.05) # <-- throttle
        except:
            time.sleep(2)
            try:
                geocoded[location] = gmaps.geocode(location)
            except:
                time.sleep(2)
                try:
                    geocoded[location] = gmaps.geocode(location)
                except:
                    geocoded[location] = 'error'
                    errors+=1
        if errors>max_errors:
            print('stopped at', iteration, '(max errors reached)')
            break
            return geocoded
        if iteration>0 and iteration%200==0:
            now = time.strftime('%H:%M:%S', time.localtime(time.time()))
            print(f'{now} | {iteration} locations geocoded ({round(iteration/len(unique_locs)*100, 2)}%) | {errors} total errors')
    print(f'job completed in {time.perf_counter() - start_time}s\n{errors} requests timed out')
    print(len([v for v in geocoded.values() if v=='error']), 'locations not found')
    return geocoded

# %%
unique_geocodes = get_gmap_geos(unique_locs)
# Out:
# 22:11:35 | 200 locations geocoded (25.71%) | 0 total errors
# 22:13:42 | 400 locations geocoded (51.41%) | 0 total errors
# 22:15:40 | 600 locations geocoded (77.12%) | 0 total errors
# job completed in 475.464760686s
# 0 requests timed out
# 0 locations not found

# %% [markdown]
# ### Map back onto df

# %%
df['gmaps_info'] = df['address'].apply(lambda x: unique_geocodes[x])

# %%
def extract_coords(geo):
    try:
        geo = geo[-1] # drop generalized extra results
        return geo['geometry']['location']['lat'], geo['geometry']['location']['lng']
    except:
        return np.nan, np.nan

# %%
df['coord'] = df['gmaps_info'].apply(extract_coords)
df['latitude'].fillna(df['coord'].apply(lambda x: x[0]), inplace=True)
df['longitude'].fillna(df['coord'].apply(lambda x: x[1]), inplace=True)
df.head()
# Out:
#       price                                              title  longitude  \
# 0  ₹ 19,000  3 BHK Apartment for rent in Vijay Shanthi Apar...  12.760201
# 1   ₹ 8,500        1 BHK House for rent in Tambaram Sanatorium  13.044208
# 2  ₹ 35,000  3 BHK Builder Floor for rent in Pushpa Nagar-N...  78.486671
# 3  ₹ 15,000         2 BHK House for rent in Velachery 950 sqft  12.979078
# 4  ₹ 15,000  2 BHK Apartment for rent in Arun Excello Sanka...  80.162565
#
#     latitude                  floor      furnishing tenants preferred  \
# 0  80.207000                    NaN             NaN               NaN
# 1  80.200531  Ground out of 1 Floor     Unfurnished         Bachelors
# 2  17.385044      2 out of 2 Floors  Semi-Furnished            Family
# 3  80.219185      1 out of 2 Floors     Unfurnished  Bachelors/Family
# 4  12.817676                    NaN             NaN               NaN
#
#    bathroom facing availability car parking  balcony owner resides  \
# 0       NaN    NaN          NaN         NaN      NaN           NaN
# 1       1.0  South  Immediately      1 Open      NaN           NaN
# 2       3.0   East  Immediately   5 Covered      1.0  Same Premise
# 3       2.0    NaN  Immediately         NaN      1.0           NaN
# 4       NaN    NaN          NaN         NaN      NaN           NaN
#
#   overlooking                                            address  \
# 0         NaN   Vijay Shanthi Apartment, Kelambakkam, Old Mah...
# 1         NaN                     Tambaram Sanatorium, Hyderabad
# 2         NaN               Pushpa Nagar-Nungambakkam, Hyderabad
# 3         NaN                               Velachery, Hyderabad
# 4         NaN         Arun Excello Sankara, Mambakkam, Hyderabad
#
#                                           gmaps_info  \
# 0  [{'address_components': [{'long_name': 'Chenna...
# 1  [{'address_components': [{'long_name': 'Tambar...
# 2  [{'address_components': [{'long_name': 'Pushpa...
# 3  [{'address_components': [{'long_name': 'Madipa...
# 4  [{'address_components': [{'long_name': 'Kelamb...
#
#                              coord
# 0         (12.7606528, 80.2079447)
# 1           (17.385044, 78.486671)
# 2           (17.385044, 78.486671)
# 3  (12.9771281, 80.22274589999999)
# 4  (12.8176758, 80.16256489999999)

# %% [markdown]
# ### Export

# %%
df.to_csv('geocoded.csv', index=False)
