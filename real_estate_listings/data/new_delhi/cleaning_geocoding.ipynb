# %% [markdown]
# # Introduction
# Processing of datasets in/around New Delhi, IN

# %% [markdown]
# ### Imports
# Import libraries and write settings here.

# %%
#import os

# Data manipulation
import pandas as pd
import numpy as np
import regex as re

# Options for pandas
pd.options.display.max_columns = 50
pd.options.display.max_rows = 30

# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

from IPython import get_ipython
ipython = get_ipython()

# autoreload extension
if 'autoreload' not in ipython.extension_manager.loaded:
    # %load_ext autoreload

# %autoreload 2
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Data Imports
# - Let **del_df** be data from [magicbricks - New Delhi - IN](https://www.magicbricks.com/property-for-sale-rent-in-New-Delhi/residential-real-estate-New-Delhi)

# %%
del_df = pd.read_csv('./data.csv', header='infer')

# %%
del_df.shape
# Out:
# (2346, 14)

# %%
print(del_df.columns)
# Out:
# Index(['price', 'title', 'longitude', 'latitude', 'floor', 'furnishing',
#        'tenants preferred', 'bathroom', 'balcony', 'availability', 'facing',
#        'overlooking', 'car parking', 'owner resides'],
#       dtype='object')

# %%
# Proportions of RE data missing
round(del_df.isna().mean() * 100, 2)
# Out:
# price                 0.00
# title                 0.00
# longitude            38.75
# latitude             38.75
# floor                20.29
# furnishing           16.84
# tenants preferred    16.79
# bathroom             17.09
# balcony              30.05
# availability         16.79
# facing               36.62
# overlooking          40.79
# car parking          64.36
# owner resides        95.40
# dtype: float64

# %%
# Data types received
del_df.dtypes
# Out:
# price                 object
# title                 object
# longitude            float64
# latitude             float64
# floor                 object
# furnishing            object
# tenants preferred     object
# bathroom              object
# balcony               object
# availability          object
# facing                object
# overlooking           object
# car parking           object
# owner resides         object
# dtype: object

# %%
# Work on the price column (type: obj) and get what we can from it
# INR / rupee mark
del_df["curr_mark"] = del_df["price"][0][0]

# Flag col on lahk designation
del_df["hasLac"] = del_df["price"].str.contains('Lac|Lahk|Lacs|Lahks', case=False, regex=True)

# Extract price per month
del_df["inr_pmo"] = del_df["price"].str.replace(',','').str.extract('(\d+(?:.)\d+)', expand=False).astype("float")

# %%
del_df.dtypes
# Out:
# price                 object
# title                 object
# longitude            float64
# latitude             float64
# floor                 object
# furnishing            object
# tenants preferred     object
# bathroom              object
# balcony               object
# availability          object
# facing                object
# overlooking           object
# car parking           object
# owner resides         object
# curr_mark             object
# hasLac                  bool
# inr_pmo              float64
# dtype: object

# %%
del_df
# Out:
#           price                                              title  longitude  \
# 0      ₹ 10,000              1 BHK Builder Floor for rent in Saket  28.523548
# 1     ₹ 1.6 Lac  4 BHK Builder Floor for rent in Greater Kailas...        NaN
# 2       ₹ 7,000        1 BHK Builder Floor for rent in Chhattarpur        NaN
# 3      ₹ 20,500  1 BHK House for rent in Dayanand Colony, Lajpa...  28.562599
# 4      ₹ 13,000       1 BHK Apartment for rent in Rohini Sector 18  28.741163
# ...         ...                                                ...        ...
# 2341   ₹ 64,000  3 BHK Builder Floor for rent in Sarvodaya Encl...  28.537321
# 2342   ₹ 50,000  2 BHK Builder Floor for rent in Vasant Vihar 4...  28.568102
# 2343   ₹ 63,000  3 BHK Builder Floor for rent in Safdarjung Enc...  28.563671
# 2344   ₹ 17,500  2 BHK Builder Floor for rent in Subhash Nagar ...  28.634584
# 2345   ₹ 10,000              2 BHK Apartment for rent in Vikaspuri  28.637766
#
#        latitude                   floor      furnishing tenants preferred  \
# 0     77.208893       2 out of 4 Floors       Furnished  Bachelors/Family
# 1           NaN       2 out of 3 Floors  Semi-Furnished  Bachelors/Family
# 2           NaN       2 out of 3 Floors  Semi-Furnished  Bachelors/Family
# 3     77.249603  Ground out of 3 Floors       Furnished  Bachelors/Family
# 4     77.134613       2 out of 4 Floors  Semi-Furnished  Bachelors/Family
# ...         ...                     ...             ...               ...
# 2341  77.203056       3 out of 4 Floors  Semi-Furnished  Bachelors/Family
# 2342  77.162636       2 out of 3 Floors     Unfurnished  Bachelors/Family
# 2343  77.190063       3 out of 3 Floors       Furnished         Bachelors
# 2344  77.049034       2 out of 3 Floors  Semi-Furnished            Family
# 2345  77.075966       1 out of 3 Floors  Semi-Furnished         Bachelors
#
#      bathroom balcony availability        facing             overlooking  \
# 0           2       1  Immediately           NaN                     NaN
# 1           4       2  Immediately         South  Garden/Park, Main Road
# 2           1     NaN  Immediately          East               Main Road
# 3           1       1  Immediately           NaN                     NaN
# 4           1       1  Immediately           NaN                     NaN
# ...       ...     ...          ...           ...                     ...
# 2341        3       3  Immediately  North - East             Garden/Park
# 2342        2       2  Immediately           NaN                     NaN
# 2343        3       3  Immediately  North - East  Garden/Park, Main Road
# 2344        2       2  Immediately          East               Main Road
# 2345        1       1  Immediately         North             Garden/Park
#
#             car parking owner resides curr_mark  hasLac  inr_pmo
# 0                   NaN           NaN         ₹   False  10000.0
# 1     1 Covered, 1 Open           NaN         ₹    True      1.6
# 2                1 Open           NaN         ₹   False   7000.0
# 3                   NaN           NaN         ₹   False  20500.0
# 4                   NaN           NaN         ₹   False  13000.0
# ...                 ...           ...       ...     ...      ...
# 2341          2 Covered  Same Premise         ₹   False  64000.0
# 2342                NaN           NaN         ₹   False  50000.0
# 2343  1 Covered, 1 Open           NaN         ₹   False  63000.0
# 2344             1 Open           NaN         ₹   False  17500.0
# 2345             1 Open           NaN         ₹   False  10000.0
#
# [2346 rows x 17 columns]

# %%
# Determine the currency mark leading the price value
del_df["curr_mark"].value_counts(dropna=False)
# Out:
# ₹    2346
# Name: curr_mark, dtype: int64

# %%
# How many Lac?
del_df["hasLac"].value_counts(dropna=True)
# Out:
# False    2057
# True      289
# Name: hasLac, dtype: int64

# %%
# Convert/calculate a new column from INR to USD as of 2020-02-16
# 100 INR = 1.4022 USD

def get_usd(row):
    if row["hasLac"]:
        usd_pmo = round(row["inr_pmo"] * 100000 * 0.014022, 2)
    else:
        usd_pmo = round(row["inr_pmo"] * 0.014022, 2)
    return usd_pmo

del_df["usd_pmo"] = del_df.apply(get_usd, axis=1)

# %%
del_df
# Out:
#           price                                              title  longitude  \
# 0      ₹ 10,000              1 BHK Builder Floor for rent in Saket  28.523548
# 1     ₹ 1.6 Lac  4 BHK Builder Floor for rent in Greater Kailas...        NaN
# 2       ₹ 7,000        1 BHK Builder Floor for rent in Chhattarpur        NaN
# 3      ₹ 20,500  1 BHK House for rent in Dayanand Colony, Lajpa...  28.562599
# 4      ₹ 13,000       1 BHK Apartment for rent in Rohini Sector 18  28.741163
# ...         ...                                                ...        ...
# 2341   ₹ 64,000  3 BHK Builder Floor for rent in Sarvodaya Encl...  28.537321
# 2342   ₹ 50,000  2 BHK Builder Floor for rent in Vasant Vihar 4...  28.568102
# 2343   ₹ 63,000  3 BHK Builder Floor for rent in Safdarjung Enc...  28.563671
# 2344   ₹ 17,500  2 BHK Builder Floor for rent in Subhash Nagar ...  28.634584
# 2345   ₹ 10,000              2 BHK Apartment for rent in Vikaspuri  28.637766
#
#        latitude                   floor      furnishing tenants preferred  \
# 0     77.208893       2 out of 4 Floors       Furnished  Bachelors/Family
# 1           NaN       2 out of 3 Floors  Semi-Furnished  Bachelors/Family
# 2           NaN       2 out of 3 Floors  Semi-Furnished  Bachelors/Family
# 3     77.249603  Ground out of 3 Floors       Furnished  Bachelors/Family
# 4     77.134613       2 out of 4 Floors  Semi-Furnished  Bachelors/Family
# ...         ...                     ...             ...               ...
# 2341  77.203056       3 out of 4 Floors  Semi-Furnished  Bachelors/Family
# 2342  77.162636       2 out of 3 Floors     Unfurnished  Bachelors/Family
# 2343  77.190063       3 out of 3 Floors       Furnished         Bachelors
# 2344  77.049034       2 out of 3 Floors  Semi-Furnished            Family
# 2345  77.075966       1 out of 3 Floors  Semi-Furnished         Bachelors
#
#      bathroom balcony availability        facing             overlooking  \
# 0           2       1  Immediately           NaN                     NaN
# 1           4       2  Immediately         South  Garden/Park, Main Road
# 2           1     NaN  Immediately          East               Main Road
# 3           1       1  Immediately           NaN                     NaN
# 4           1       1  Immediately           NaN                     NaN
# ...       ...     ...          ...           ...                     ...
# 2341        3       3  Immediately  North - East             Garden/Park
# 2342        2       2  Immediately           NaN                     NaN
# 2343        3       3  Immediately  North - East  Garden/Park, Main Road
# 2344        2       2  Immediately          East               Main Road
# 2345        1       1  Immediately         North             Garden/Park
#
#             car parking owner resides curr_mark  hasLac  inr_pmo  usd_pmo
# 0                   NaN           NaN         ₹   False  10000.0   140.22
# 1     1 Covered, 1 Open           NaN         ₹    True      1.6  2243.52
# 2                1 Open           NaN         ₹   False   7000.0    98.15
# 3                   NaN           NaN         ₹   False  20500.0   287.45
# 4                   NaN           NaN         ₹   False  13000.0   182.29
# ...                 ...           ...       ...     ...      ...      ...
# 2341          2 Covered  Same Premise         ₹   False  64000.0   897.41
# 2342                NaN           NaN         ₹   False  50000.0   701.10
# 2343  1 Covered, 1 Open           NaN         ₹   False  63000.0   883.39
# 2344             1 Open           NaN         ₹   False  17500.0   245.38
# 2345             1 Open           NaN         ₹   False  10000.0   140.22
#
# [2346 rows x 18 columns]

# %%
# @@FIX@@ LatLong are reversed in the dataframe!
del_df.rename(columns={'longitude':'latitude_x', 'latitude':'longitude_x'}, inplace=True)

# %%
# @@FIX@@ LatLong are reversed in the dataframe!
del_df.rename(columns={'latitude_x':'latitude', 'longitude_x':'longitude'}, inplace=True)

# %%
del_df.head()
# Out:
#        price                                              title   latitude  \
# 0   ₹ 10,000              1 BHK Builder Floor for rent in Saket  28.523548
# 1  ₹ 1.6 Lac  4 BHK Builder Floor for rent in Greater Kailas...        NaN
# 2    ₹ 7,000        1 BHK Builder Floor for rent in Chhattarpur        NaN
# 3   ₹ 20,500  1 BHK House for rent in Dayanand Colony, Lajpa...  28.562599
# 4   ₹ 13,000       1 BHK Apartment for rent in Rohini Sector 18  28.741163
#
#    longitude                   floor      furnishing tenants preferred  \
# 0  77.208893       2 out of 4 Floors       Furnished  Bachelors/Family
# 1        NaN       2 out of 3 Floors  Semi-Furnished  Bachelors/Family
# 2        NaN       2 out of 3 Floors  Semi-Furnished  Bachelors/Family
# 3  77.249603  Ground out of 3 Floors       Furnished  Bachelors/Family
# 4  77.134613       2 out of 4 Floors  Semi-Furnished  Bachelors/Family
#
#   bathroom balcony availability facing             overlooking  \
# 0        2       1  Immediately    NaN                     NaN
# 1        4       2  Immediately  South  Garden/Park, Main Road
# 2        1     NaN  Immediately   East               Main Road
# 3        1       1  Immediately    NaN                     NaN
# 4        1       1  Immediately    NaN                     NaN
#
#          car parking owner resides curr_mark  hasLac  inr_pmo  usd_pmo
# 0                NaN           NaN         ₹   False  10000.0   140.22
# 1  1 Covered, 1 Open           NaN         ₹    True      1.6  2243.52
# 2             1 Open           NaN         ₹   False   7000.0    98.15
# 3                NaN           NaN         ₹   False  20500.0   287.45
# 4                NaN           NaN         ₹   False  13000.0   182.29

# %%
# Capture a dataframe with just the missing LatLong
no_latlong = del_df[del_df['latitude'].isnull() | del_df['longitude'].isnull()]

# %%
no_latlong = no_latlong[no_latlong.columns[1:2]]

# %%
no_latlong.head()
# Out:
#                                                 title
# 1   4 BHK Builder Floor for rent in Greater Kailas...
# 2         1 BHK Builder Floor for rent in Chhattarpur
# 9   2 BHK Builder Floor for rent in Uttam Nagar We...
# 10  2 BHK Builder Floor for rent in Uttam Nagar We...
# 11  2 BHK Builder Floor for rent in Vinod Nagar Ea...

# %%
# Testing
# no_latlong["title"].str.partition("in")

no_latlong[['description', 'neighborhood']] = no_latlong['title'].str.split(pat=' in ',expand=True)
# Got: ValueError: Columns must be same length as key

# %%
no_latlong
# Out:
#                                                   title  \
# 1     4 BHK Builder Floor for rent in Greater Kailas...
# 2           1 BHK Builder Floor for rent in Chhattarpur
# 9     2 BHK Builder Floor for rent in Uttam Nagar We...
# 10    2 BHK Builder Floor for rent in Uttam Nagar We...
# 11    2 BHK Builder Floor for rent in Vinod Nagar Ea...
# ...                                                 ...
# 2314  4 BHK Builder Floor for rent in Safdarjung Enc...
# 2315  3 BHK Builder Floor for rent in Safdarjung Enc...
# 2317  4 BHK House for rent in Shivalik, Malviya Naga...
# 2325  2 BHK Builder Floor for rent in Vasant Vihar 1...
# 2339  3 BHK Builder Floor for rent in South Extensio...
#
#                        description                             neighborhood
# 1     4 BHK Builder Floor for rent              Greater Kailash 1 3200 sqft
# 2     1 BHK Builder Floor for rent                              Chhattarpur
# 9     2 BHK Builder Floor for rent                Uttam Nagar West 675 sqft
# 10    2 BHK Builder Floor for rent                Uttam Nagar West 850 sqft
# 11    2 BHK Builder Floor for rent                Vinod Nagar East 55 sqyrd
# ...                            ...                                      ...
# 2314  4 BHK Builder Floor for rent             Safdarjung Enclave 6400 sqft
# 2315  3 BHK Builder Floor for rent             Safdarjung Enclave 1500 sqft
# 2317          4 BHK House for rent        Shivalik, Malviya Nagar 3100 sqft
# 2325  2 BHK Builder Floor for rent                   Vasant Vihar 1500 sqft
# 2339  3 BHK Builder Floor for rent  South Extension 2, South Ex 2 1900 sqft
#
# [909 rows x 3 columns]

# %%
# Continue tweaking... remove the household area from the 'neighborhood' column
no_latlong[["neighborhood_clean", "ext", "space", "junk"]] = no_latlong['neighborhood'].str.split(r'\d+',expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-166-3413bc0f7eb9> in <module>
#       1 # Continue tweaking... remove the household area from the 'neighborhood' column
# ----> 2 no_latlong[["neighborhood_clean", "ext", "space", "junk"]] = no_latlong['neighborhood'].str.split(r'\d+',expand=True).strip()
#
# /opt/anaconda3/envs/dsi/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'strip'

# %%
no_latlong
# Out:
#                                                   title  \
# 1     4 BHK Builder Floor for rent in Greater Kailas...
# 2           1 BHK Builder Floor for rent in Chhattarpur
# 9     2 BHK Builder Floor for rent in Uttam Nagar We...
# 10    2 BHK Builder Floor for rent in Uttam Nagar We...
# 11    2 BHK Builder Floor for rent in Vinod Nagar Ea...
# ...                                                 ...
# 2314  4 BHK Builder Floor for rent in Safdarjung Enc...
# 2315  3 BHK Builder Floor for rent in Safdarjung Enc...
# 2317  4 BHK House for rent in Shivalik, Malviya Naga...
# 2325  2 BHK Builder Floor for rent in Vasant Vihar 1...
# 2339  3 BHK Builder Floor for rent in South Extensio...
#
#                        description                             neighborhood  \
# 1     4 BHK Builder Floor for rent              Greater Kailash 1 3200 sqft
# 2     1 BHK Builder Floor for rent                              Chhattarpur
# 9     2 BHK Builder Floor for rent                Uttam Nagar West 675 sqft
# 10    2 BHK Builder Floor for rent                Uttam Nagar West 850 sqft
# 11    2 BHK Builder Floor for rent                Vinod Nagar East 55 sqyrd
# ...                            ...                                      ...
# 2314  4 BHK Builder Floor for rent             Safdarjung Enclave 6400 sqft
# 2315  3 BHK Builder Floor for rent             Safdarjung Enclave 1500 sqft
# 2317          4 BHK House for rent        Shivalik, Malviya Nagar 3100 sqft
# 2325  2 BHK Builder Floor for rent                   Vasant Vihar 1500 sqft
# 2339  3 BHK Builder Floor for rent  South Extension 2, South Ex 2 1900 sqft
#
#             neighborhood_clean          ext  space   junk
# 1             Greater Kailash                 sqft   None
# 2                  Chhattarpur         None   None   None
# 9            Uttam Nagar West          sqft   None   None
# 10           Uttam Nagar West          sqft   None   None
# 11           Vinod Nagar East         sqyrd   None   None
# ...                        ...          ...    ...    ...
# 2314       Safdarjung Enclave          sqft   None   None
# 2315       Safdarjung Enclave          sqft   None   None
# 2317  Shivalik, Malviya Nagar          sqft   None   None
# 2325             Vasant Vihar          sqft   None   None
# 2339          South Extension   , South Ex           sqft
#
# [909 rows x 7 columns]

# %%
pd.options.display.max_rows = 350
no_latlong["neighborhood_clean"].value_counts(dropna=False)
# Out:
# Greater Kailash                                      77
# Dwarka Sector                                        30
# Safdarjung Enclave                                   27
# Vasant Vihar                                         19
# Rohini Sector                                        19
# Lajpat Nagar                                         18
# Defence Colony                                       18
# Paschim Vihar                                        17
# Gulmohar Park                                        15
# Chhattarpur                                          14
# Saket                                                13
# Panchsheel Park                                      13
# Sarvapriya Vihar                                     13
# Uday Park, South Extension                           12
# Mayur Vihar                                          12
# Panchsheel Enclave                                   11
# Malviya Nagar                                        10
# Safdarjung Development Area, Hauz Khas               10
# Sarvodaya Enclave                                     9
# Hauz Khas                                             9
# Preet Vihar                                           8
# Kalkaji                                               8
# Pitampura                                             7
# Janakpuri                                             7
# Old Rajendra Nagar, Rajinder Nagar                    7
# Nizamuddin East, Nizamuddin                           7
# South Extension                                       7
# Shanti Niketan                                        6
# East Of Kailash                                       6
# Paschim Vihar                                         6
# Saket                                                 6
# Old Rajendra Nagar, Rajinder Nagar                    6
# Shivalik, Malviya Nagar                               6
# Laxmi Nagar                                           6
# Munirka                                               6
# Green Park                                            6
# Anand Niketan                                         6
# Jangpura Extension, Jangpura                          5
# Gagan Vihar, Krishna Nagar                            5
# Vikaspuri                                             5
# Virender Nagar                                        4
# New Friends Colony                                    4
# Vasant Kunj                                           4
# Kailash Colony, Greater Kailash                       4
# Uttam Nagar West                                      4
# Dwarka Mor                                            4
# Chanakyapuri                                          4
# Hauz Khas Enclave, Hauz Khas                          4
# Anand Vihar                                           4
# Chhattarpur                                           4
# Greater Kailash Enclave                               4
# Vikaspuri Block C                                     3
# Dayanand Vihar, Anand Vihar                           3
# Burari                                                3
# Mehrauli                                              3
# Sukhdev Vihar, Okhla                                  3
# Sainik Farm                                           3
# Alaknanda                                             3
# Green Park Extension                                  3
# Malviya Nagar                                         3
# Surya Niketan, Anand Vihar                            3
# Shakarpur                                             3
# Kalkaji                                               3
# Najafgarh                                             3
# Govindpuri Main                                       3
# Paschim Vihar Block A                                 3
# Tilak Nagar                                           3
# Vivek Vihar                                           3
# Rajouri Garden                                        3
# Patel Nagar West                                      3
# Vikaspuri                                             3
# Sant Nagar Near East of Kailash, East of Kailash      3
# Janakpuri                                             3
# Sarita Vihar, Mathura Road                            3
# Vikaspuri Block D                                     3
# Kalkaji Extention                                     2
# Amar Colony, Lajpat Nagar                             2
# Kohat Enclave, Pitampura                              2
# Rajpur Khurd Extension, Rajpur                        2
# Indraprastha Extension, Patparganj                    2
# Dallupura                                             2
# Aya Nagar                                             2
# Subhash Nagar                                         2
# Ramesh Nagar                                          2
# Ram Vihar, Anand Vihar                                2
# Paschim Vihar Block B                                 2
# Karkardooma, Anand Vihar                              2
# Vinod Nagar East                                      2
# Jangpura                                              2
# Govindpuri Extension, Kalkaji                         2
# Shahdara                                              2
# Laxmi Nagar                                           2
# Navjivan Vihar, Adchini                               2
# Mansarover Garden                                     2
# Chanakya Place                                        2
# Defence Colony                                        2
# Patel Nagar                                           2
# Paryavaran Complex, Sainik Farm                       2
# Paryavaran Complex, Sainik Farm                       2
# Mahipalpur                                            2
# Yojna Vihar, Anand Vihar                              2
# Malka Ganj                                            2
# Mahavir Enclave Part                                  2
# Pochanpur Colony, Dwarka                              2
# New Rajendra Nagar                                    2
# Nangli Sakrawati                                      2
# Mandi, Mahipalpur                                     2
# Tagore Garden, Rajouri Garden, Najafgarh Road         2
# DDA Flats Sector-                                     2
# Mianwali Nagar, Paschim Vihar                         2
# Soami Nagar                                           2
# Raja Puri, Matiala                                    2
# Vasant Kunj Sector D                                  2
# Vivek Vihar Phase                                     2
# Chitra Vihar, Swasthya Vihar                          2
# Patel Nagar East, Patel Nagar                         2
# Neb Sarai, Sainik Farm                                2
# Ashok Vihar Phase                                     2
# Subhash Nagar                                         2
# Surajmal Vihar                                        2
# Rajpur Khurd Extension, Rajpur                        2
# Neeti Bagh                                            2
# New Ashok Nagar                                       2
# Chittaranjan Park                                     2
# Harsh Vihar, Mandoli                                  2
# Hari Nagar                                            1
# Bhera Enclave, Paschim Vihar                          1
# Vijay Nagar                                           1
# Humayunpur, Safdarjung Enclave                        1
# Dilshad Garden                                        1
# Munirka Vihar, Munirka                                1
# Mithapur Extension, Mithapur                          1
# Rajouri Garden                                        1
# Moti Nagar, Kirti Nagar                               1
# Chander Vihar, Nilothi                                1
# Ganesh Market, Kirti Nagar                            1
# Ramesh Nagar                                          1
# New Delhi Estate Apartments, Dwarka Sector            1
# Punjabi Bagh West                                     1
# Sundar Nagar                                          1
# Vishwakarma Colony, Mehrauli Badarpur Road            1
# East Of Kailash Block F                               1
# Madanpur Khader                                       1
# Shadipur                                              1
# Jagatpuri, Krishna Nagar                              1
# Shahdara                                              1
# Gewtanjali Park,Sagarpur West                         1
# Anand Niketan Block D                                 1
# Hari Nagar                                            1
# Tagore Garden Extension, Rajouri Garden               1
# Vinod Nagar East                                      1
# Vishal Enclave, Tagore Garden Extension               1
# Bharthal, Dwarka                                      1
# Rohini                                                1
# New Rajendra Nagar                                    1
# Guru Teg Bahadur Nagar                                1
# C                                                     1
# Nauroji Nagar, Safdarjung Enclave                     1
# Jangpura Extension, Jangpura                          1
# Khanpur, Madangir                                     1
# Boutique Residential, Greater Kailash                 1
# Uppal Builder Floors, New Delhi                       1
# Nehru Place                                           1
# Dwarka                                                1
# Pandav Nagar                                          1
# Gautam Nagar                                          1
# Nawada                                                1
# Freedom Fighters Enclave                              1
# Amar Colony, Lajpat Nagar                             1
# Model Town Phase                                      1
# Dakshini Pitampura                                    1
# Arjun Nagar, Safdarjung Enclave                       1
# East Of Kailash                                       1
# Vikaspuri Block G                                     1
# Selcon Builder Floors, Panchsheel Park                1
# Molarband Block F, Molarband                          1
# Tilak Nagar                                           1
# Vishwas Nagar Extension, Shahdara                     1
# New Mahavir Nagar, Tilak Nagar                        1
# Vasant Kunj Sector C                                  1
# Vasundhara Enclave                                    1
# Sarita Vihar Pocket D                                 1
# Pitampura                                             1
# Janakpuri Block C                                     1
# Upadhyay Block, Shakarpur                             1
# Uttam Nagar                                           1
# Giri Nagar, KalkaJi                                   1
# Gulmohar Park                                         1
# Savitri Nagar Village, Sheikh Sarai                   1
# New Manglapuri, Sultanpur                             1
# Golf Links                                            1
# Jagriti Enclave, Anand Vihar                          1
# Connaught Place                                       1
# Gangotri Enclave, Alaknanda                           1
# Vasant Kunj Sector B                                  1
# Najafgarh                                             1
# Dwarka Mor                                            1
# Shahabad Daulatpur, Rohini                            1
# Vikaspuri Block KG-                                   1
# Govindpuri Extension, Kalkaji                         1
# Uttam Nagar East, Uttam Nagar                         1
# New Delhi                                             1
# Molarband Extension, Badarpur                         1
# Acharya Niketan, Mayur Vihar                          1
# Jor Bagh                                              1
# Sukhbir Nagar                                         1
# New Rajdhani Enclave, Swasthya Vihar                  1
# Mehrauli Village, Mehrauli                            1
# Gopi Apertment Dwarka Sector                          1
# Milap Nagar, Uttam Nagar                              1
# Vijay Vihar, Rohini                                   1
# Saraswati Vihar, Pitampura                            1
# AGCR Enclave, Anand Vihar                             1
# Patel Nagar South, Patel Nagar                        1
# Kailash hills, East Of Kailash                        1
# Sharda Puri, Ramesh Nagar                             1
# Ashram                                                1
# Golf Links                                            1
# Anand Lok                                             1
# I P Extension                                         1
# Kamla Nagar                                           1
# Devli, Sangam Vihar                                   1
# Uttam Nagar                                           1
# Shakarpur Khas, Shakarpur                             1
# Prem Nagar                                            1
# Mahavir Enclave                                       1
# Jangpura A, Jangpura                                  1
# Swasthya Vihar                                        1
# Pochanpur Colony, Dwarka                              1
# Gulmohar Enclave, Gulmohar Park                       1
# Maharani Bagh, New Friends Colony                     1
# Safdarjung Enclave                                    1
# Ber Sarai                                             1
# Trilokpuri                                            1
# Govindpuri Main                                       1
# Mohan Garden, Razapur Khurd                           1
# Vikaspuri Block M                                     1
# Ranfal chowk                                          1
# Taimoor Nagar, New Friends Colony                     1
# Dilshad Colony, Dilshad Garden                        1
# Chuna Mandi, Paharganj                                1
# Sirifort Road                                         1
# Mandawali                                             1
# Nirankari Colony, Mukherjee Nagar                     1
# Ber Sarai                                             1
# Matiala                                               1
# Kailash Colony, Greater Kailash                       1
# Bengali Market, Mandi House                           1
# Sadh Nagar, Palam                                     1
# Lajpat Nagar II                                       1
# Sultanpur                                             1
# Sagarpur East, Sagarpur                               1
# Shashi Garden, Mayur Vihar                            1
# Ashoka Niketan, Anand Vihar                           1
# Mahaveer Nagar, South Extension                       1
# Nangli Sakrawati                                      1
# Dashrathpuri                                          1
# Patparganj                                            1
# Navjeevan Vihar, Navjivan Vihar, Adchini              1
# Rajouri Garden Extension, Rajouri Garden              1
# Vikaspuri Block F                                     1
# Nizamuddin West, Nizamuddin                           1
# railway station                                       1
# Kakrola, Kakrola                                      1
# East Of Kailash Block B                               1
# Sainik Nagar, Uttam Nagar                             1
# Pahar Ganj                                            1
# Krishna Nagar,s.j.enclave                             1
# Basai Darapur, Bali Nagar                             1
# Palam Colony, Palam                                   1
# Ashok Nagar                                           1
# Guru Arjun Nagar, Shadipur                            1
# Sewak Park, Dwarka                                    1
# Patel Nagar West                                      1
# Sarita Vihar Pocket L                                 1
# Baljit Nagar, Patel Nagar                             1
# Aya Nagar Extension                                   1
# Vipin Garden, Nawada                                  1
# Rajouri Garden Extension, Rajouri Garden              1
# Bharat Jagriti Apartment, Dwarka Sector               1
# Dadri Road, Dabri                                     1
# Bhajanpura, Shahdara                                  1
# Gautam Nagar                                          1
# Old Gupta Colony, Kalyan Vihar                        1
# Chanakya Place, Sitapuri                              1
# Taimoor Nagar, New Friends Colony                     1
# Sant Nagar Near East of Kailash, East of Kailash      1
# New Friends Colony                                    1
# Nangloi                                               1
# Sangam Vihar                                          1
# Nirman Vihar, Preet Vihar                             1
# Panchsheel Enclave                                    1
# Valmax Builder Floors, Greater Kailash                1
# Bhajanpura, Shahdara                                  1
# Shyam Vihar                                           1
# Sangam Vihar                                          1
# Mohan Garden, Razapur Khurd                           1
# Mangolpuri                                            1
# Bhogal, Jangpura                                      1
# Defence colony Villas, Defence Colony                 1
# Chajju ram colony Nangloi                             1
# Space Elena, New Delhi                                1
# Patparganj                                            1
# Uppal Builder Floors, Panchsheel Park                 1
# West End                                              1
# Sri Niwaspuri                                         1
# Patel Garden, Dwarka                                  1
# Tarun Enclave, Pitampura                              1
# New Kondli, Kondli                                    1
# Subhash Park, Shahdara                                1
# Janakpuri Block B                                     1
# IGNOU Road, Saket                                     1
# Mundka                                                1
# Vasant Kunj Sector C                                  1
# Palam                                                 1
# der sarai                                             1
# Manak Vihar, Anand Vihar                              1
# Sadhna Enclave, Panchsheel Park                       1
# Madipur, Punjabi Bagh                                 1
# Safdarjung                                            1
# Uttari Pitampura                                      1
# Janakpuri Block A                                     1
# Narela                                                1
# Kailash hills, East Of Kailash                        1
# Tughlakabad Extension                                 1
# Vikaspuri Block H                                     1
# Name: neighborhood_clean, dtype: int64

# %%
# Add geocodes to neighborhood of MISSING
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

geolocator = Nominatim(user_agent="GA_GeoCoder")

# Invoke rate-limited geocode
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# Now create location column
no_latlong['location'] = no_latlong['neighborhood_clean'].apply(lambda x : x + ', India').apply(geocode)

# Credit: [GeoPy](https://geopy.readthedocs.io/en/stable/)
#         [towardsdatascience/geocode-with-python](http://bit.ly/2ueKREg

# %%
no_latlong
# Out:
#                                                   title  \
# 1     4 BHK Builder Floor for rent in Greater Kailas...
# 2           1 BHK Builder Floor for rent in Chhattarpur
# 9     2 BHK Builder Floor for rent in Uttam Nagar We...
# 10    2 BHK Builder Floor for rent in Uttam Nagar We...
# 11    2 BHK Builder Floor for rent in Vinod Nagar Ea...
# ...                                                 ...
# 2314  4 BHK Builder Floor for rent in Safdarjung Enc...
# 2315  3 BHK Builder Floor for rent in Safdarjung Enc...
# 2317  4 BHK House for rent in Shivalik, Malviya Naga...
# 2325  2 BHK Builder Floor for rent in Vasant Vihar 1...
# 2339  3 BHK Builder Floor for rent in South Extensio...
#
#                        description                             neighborhood  \
# 1     4 BHK Builder Floor for rent              Greater Kailash 1 3200 sqft
# 2     1 BHK Builder Floor for rent                              Chhattarpur
# 9     2 BHK Builder Floor for rent                Uttam Nagar West 675 sqft
# 10    2 BHK Builder Floor for rent                Uttam Nagar West 850 sqft
# 11    2 BHK Builder Floor for rent                Vinod Nagar East 55 sqyrd
# ...                            ...                                      ...
# 2314  4 BHK Builder Floor for rent             Safdarjung Enclave 6400 sqft
# 2315  3 BHK Builder Floor for rent             Safdarjung Enclave 1500 sqft
# 2317          4 BHK House for rent        Shivalik, Malviya Nagar 3100 sqft
# 2325  2 BHK Builder Floor for rent                   Vasant Vihar 1500 sqft
# 2339  3 BHK Builder Floor for rent  South Extension 2, South Ex 2 1900 sqft
#
#             neighborhood_clean          ext  space   junk  \
# 1             Greater Kailash                 sqft   None
# 2                  Chhattarpur         None   None   None
# 9            Uttam Nagar West          sqft   None   None
# 10           Uttam Nagar West          sqft   None   None
# 11           Vinod Nagar East         sqyrd   None   None
# ...                        ...          ...    ...    ...
# 2314       Safdarjung Enclave          sqft   None   None
# 2315       Safdarjung Enclave          sqft   None   None
# 2317  Shivalik, Malviya Nagar          sqft   None   None
# 2325             Vasant Vihar          sqft   None   None
# 2339          South Extension   , South Ex           sqft
#
#                                                location
# 1     (Greater Kailash, Batala, Batala Tahsil, Gurda...
# 2     (Chhattarpur, Acharya Shri Tulsi Marg, Chattar...
# 9     (Uttam Nagar West, Shivaji Marg, R Block, Nawa...
# 10    (Uttam Nagar West, Shivaji Marg, R Block, Nawa...
# 11    (Vinod Nagar, Preet Vihar Tehsil, East Delhi, ...
# ...                                                 ...
# 2314  (Safdarjung Enclave, Vasant Vihar Tehsil, New ...
# 2315  (Safdarjung Enclave, Vasant Vihar Tehsil, New ...
# 2317                                               None
# 2325  (Vasant Vihar, Delhi Cantonment, New Delhi, De...
# 2339  (South Extension, Mahatma Gandhi Marg, Yusuf S...
#
# [909 rows x 8 columns]

# %%
# Create longitude, latitude and altitude from location column (returns tuple)
no_latlong['point'] = no_latlong['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# Split point column into latitude, longitude and altitude columns
no_latlong[['latitude', 'longitude', 'altitude']] = pd.DataFrame(no_latlong['point'].tolist(), index=no_latlong.index)

# %%
no_latlong
# Out:
#                                                   title  \
# 1     4 BHK Builder Floor for rent in Greater Kailas...
# 2           1 BHK Builder Floor for rent in Chhattarpur
# 9     2 BHK Builder Floor for rent in Uttam Nagar We...
# 10    2 BHK Builder Floor for rent in Uttam Nagar We...
# 11    2 BHK Builder Floor for rent in Vinod Nagar Ea...
# ...                                                 ...
# 2314  4 BHK Builder Floor for rent in Safdarjung Enc...
# 2315  3 BHK Builder Floor for rent in Safdarjung Enc...
# 2317  4 BHK House for rent in Shivalik, Malviya Naga...
# 2325  2 BHK Builder Floor for rent in Vasant Vihar 1...
# 2339  3 BHK Builder Floor for rent in South Extensio...
#
#                        description                             neighborhood  \
# 1     4 BHK Builder Floor for rent              Greater Kailash 1 3200 sqft
# 2     1 BHK Builder Floor for rent                              Chhattarpur
# 9     2 BHK Builder Floor for rent                Uttam Nagar West 675 sqft
# 10    2 BHK Builder Floor for rent                Uttam Nagar West 850 sqft
# 11    2 BHK Builder Floor for rent                Vinod Nagar East 55 sqyrd
# ...                            ...                                      ...
# 2314  4 BHK Builder Floor for rent             Safdarjung Enclave 6400 sqft
# 2315  3 BHK Builder Floor for rent             Safdarjung Enclave 1500 sqft
# 2317          4 BHK House for rent        Shivalik, Malviya Nagar 3100 sqft
# 2325  2 BHK Builder Floor for rent                   Vasant Vihar 1500 sqft
# 2339  3 BHK Builder Floor for rent  South Extension 2, South Ex 2 1900 sqft
#
#             neighborhood_clean          ext  space   junk  \
# 1             Greater Kailash                 sqft   None
# 2                  Chhattarpur         None   None   None
# 9            Uttam Nagar West          sqft   None   None
# 10           Uttam Nagar West          sqft   None   None
# 11           Vinod Nagar East         sqyrd   None   None
# ...                        ...          ...    ...    ...
# 2314       Safdarjung Enclave          sqft   None   None
# 2315       Safdarjung Enclave          sqft   None   None
# 2317  Shivalik, Malviya Nagar          sqft   None   None
# 2325             Vasant Vihar          sqft   None   None
# 2339          South Extension   , South Ex           sqft
#
#                                                location  \
# 1     (Greater Kailash, Batala, Batala Tahsil, Gurda...
# 2     (Chhattarpur, Acharya Shri Tulsi Marg, Chattar...
# 9     (Uttam Nagar West, Shivaji Marg, R Block, Nawa...
# 10    (Uttam Nagar West, Shivaji Marg, R Block, Nawa...
# 11    (Vinod Nagar, Preet Vihar Tehsil, East Delhi, ...
# ...                                                 ...
# 2314  (Safdarjung Enclave, Vasant Vihar Tehsil, New ...
# 2315  (Safdarjung Enclave, Vasant Vihar Tehsil, New ...
# 2317                                               None
# 2325  (Vasant Vihar, Delhi Cantonment, New Delhi, De...
# 2339  (South Extension, Mahatma Gandhi Marg, Yusuf S...
#
#                                       point   latitude  longitude  altitude
# 1             (31.8164399, 75.2218363, 0.0)  31.816440  75.221836       0.0
# 2             (28.5070073, 77.1754171, 0.0)  28.507007  77.175417       0.0
# 9              (28.621757, 77.0557122, 0.0)  28.621757  77.055712       0.0
# 10             (28.621757, 77.0557122, 0.0)  28.621757  77.055712       0.0
# 11      (28.623803, 77.29837773694399, 0.0)  28.623803  77.298378       0.0
# ...                                     ...        ...        ...       ...
# 2314          (28.5656419, 77.1934382, 0.0)  28.565642  77.193438       0.0
# 2315          (28.5656419, 77.1934382, 0.0)  28.565642  77.193438       0.0
# 2317                                   None        NaN        NaN       NaN
# 2325  (28.56069055, 77.16079073168567, 0.0)  28.560691  77.160791       0.0
# 2339          (28.5687149, 77.2168955, 0.0)  28.568715  77.216896       0.0
#
# [909 rows x 12 columns]

# %%
# Pare down to the essential missing cols
point_idx_df = no_latlong[['point', 'longitude', 'latitude']]

# %%
# Merging in the missed entries to a copy of the del_df dataset
tmp_df = pd.merge(del_df, point_idx_df, right_index=True, left_index=True, how="left", suffixes=('_left', '_right'))

# %%
# Check process
tmp_df
# Out:
#           price                                              title  \
# 0      ₹ 10,000              1 BHK Builder Floor for rent in Saket
# 1     ₹ 1.6 Lac  4 BHK Builder Floor for rent in Greater Kailas...
# 2       ₹ 7,000        1 BHK Builder Floor for rent in Chhattarpur
# 3      ₹ 20,500  1 BHK House for rent in Dayanand Colony, Lajpa...
# 4      ₹ 13,000       1 BHK Apartment for rent in Rohini Sector 18
# ...         ...                                                ...
# 2341   ₹ 64,000  3 BHK Builder Floor for rent in Sarvodaya Encl...
# 2342   ₹ 50,000  2 BHK Builder Floor for rent in Vasant Vihar 4...
# 2343   ₹ 63,000  3 BHK Builder Floor for rent in Safdarjung Enc...
# 2344   ₹ 17,500  2 BHK Builder Floor for rent in Subhash Nagar ...
# 2345   ₹ 10,000              2 BHK Apartment for rent in Vikaspuri
#
#       latitude_left  longitude_left                   floor      furnishing  \
# 0         28.523548       77.208893       2 out of 4 Floors       Furnished
# 1               NaN             NaN       2 out of 3 Floors  Semi-Furnished
# 2               NaN             NaN       2 out of 3 Floors  Semi-Furnished
# 3         28.562599       77.249603  Ground out of 3 Floors       Furnished
# 4         28.741163       77.134613       2 out of 4 Floors  Semi-Furnished
# ...             ...             ...                     ...             ...
# 2341      28.537321       77.203056       3 out of 4 Floors  Semi-Furnished
# 2342      28.568102       77.162636       2 out of 3 Floors     Unfurnished
# 2343      28.563671       77.190063       3 out of 3 Floors       Furnished
# 2344      28.634584       77.049034       2 out of 3 Floors  Semi-Furnished
# 2345      28.637766       77.075966       1 out of 3 Floors  Semi-Furnished
#
#      tenants preferred bathroom balcony availability        facing  \
# 0     Bachelors/Family        2       1  Immediately           NaN
# 1     Bachelors/Family        4       2  Immediately         South
# 2     Bachelors/Family        1     NaN  Immediately          East
# 3     Bachelors/Family        1       1  Immediately           NaN
# 4     Bachelors/Family        1       1  Immediately           NaN
# ...                ...      ...     ...          ...           ...
# 2341  Bachelors/Family        3       3  Immediately  North - East
# 2342  Bachelors/Family        2       2  Immediately           NaN
# 2343         Bachelors        3       3  Immediately  North - East
# 2344            Family        2       2  Immediately          East
# 2345         Bachelors        1       1  Immediately         North
#
#                  overlooking        car parking owner resides curr_mark  \
# 0                        NaN                NaN           NaN         ₹
# 1     Garden/Park, Main Road  1 Covered, 1 Open           NaN         ₹
# 2                  Main Road             1 Open           NaN         ₹
# 3                        NaN                NaN           NaN         ₹
# 4                        NaN                NaN           NaN         ₹
# ...                      ...                ...           ...       ...
# 2341             Garden/Park          2 Covered  Same Premise         ₹
# 2342                     NaN                NaN           NaN         ₹
# 2343  Garden/Park, Main Road  1 Covered, 1 Open           NaN         ₹
# 2344               Main Road             1 Open           NaN         ₹
# 2345             Garden/Park             1 Open           NaN         ₹
#
#       hasLac  inr_pmo  usd_pmo                          point  \
# 0      False  10000.0   140.22                            NaN
# 1       True      1.6  2243.52  (31.8164399, 75.2218363, 0.0)
# 2      False   7000.0    98.15  (28.5070073, 77.1754171, 0.0)
# 3      False  20500.0   287.45                            NaN
# 4      False  13000.0   182.29                            NaN
# ...      ...      ...      ...                            ...
# 2341   False  64000.0   897.41                            NaN
# 2342   False  50000.0   701.10                            NaN
# 2343   False  63000.0   883.39                            NaN
# 2344   False  17500.0   245.38                            NaN
# 2345   False  10000.0   140.22                            NaN
#
#       longitude_right  latitude_right
# 0                 NaN             NaN
# 1           75.221836       31.816440
# 2           77.175417       28.507007
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 2341              NaN             NaN
# 2342              NaN             NaN
# 2343              NaN             NaN
# 2344              NaN             NaN
# 2345              NaN             NaN
#
# [2346 rows x 21 columns]

# %%
# Pull over the "found" entry on None for latitude
tmp_df['latitude_left'] = np.where(np.isnan(tmp_df['latitude_left']), tmp_df['latitude_right'], tmp_df['latitude_left'])

# %%
# Pull over the "found" entry on None for longitude
tmp_df['longitude_left'] = np.where(np.isnan(tmp_df['longitude_left']), tmp_df['longitude_right'], tmp_df['longitude_left'])

# %%
# Check process
tmp_df
# Out:
#           price                                              title  \
# 0      ₹ 10,000              1 BHK Builder Floor for rent in Saket
# 1     ₹ 1.6 Lac  4 BHK Builder Floor for rent in Greater Kailas...
# 2       ₹ 7,000        1 BHK Builder Floor for rent in Chhattarpur
# 3      ₹ 20,500  1 BHK House for rent in Dayanand Colony, Lajpa...
# 4      ₹ 13,000       1 BHK Apartment for rent in Rohini Sector 18
# ...         ...                                                ...
# 2341   ₹ 64,000  3 BHK Builder Floor for rent in Sarvodaya Encl...
# 2342   ₹ 50,000  2 BHK Builder Floor for rent in Vasant Vihar 4...
# 2343   ₹ 63,000  3 BHK Builder Floor for rent in Safdarjung Enc...
# 2344   ₹ 17,500  2 BHK Builder Floor for rent in Subhash Nagar ...
# 2345   ₹ 10,000              2 BHK Apartment for rent in Vikaspuri
#
#       latitude_left  longitude_left                   floor      furnishing  \
# 0         28.523548       77.208893       2 out of 4 Floors       Furnished
# 1         31.816440       75.221836       2 out of 3 Floors  Semi-Furnished
# 2         28.507007       77.175417       2 out of 3 Floors  Semi-Furnished
# 3         28.562599       77.249603  Ground out of 3 Floors       Furnished
# 4         28.741163       77.134613       2 out of 4 Floors  Semi-Furnished
# ...             ...             ...                     ...             ...
# 2341      28.537321       77.203056       3 out of 4 Floors  Semi-Furnished
# 2342      28.568102       77.162636       2 out of 3 Floors     Unfurnished
# 2343      28.563671       77.190063       3 out of 3 Floors       Furnished
# 2344      28.634584       77.049034       2 out of 3 Floors  Semi-Furnished
# 2345      28.637766       77.075966       1 out of 3 Floors  Semi-Furnished
#
#      tenants preferred bathroom balcony availability        facing  \
# 0     Bachelors/Family        2       1  Immediately           NaN
# 1     Bachelors/Family        4       2  Immediately         South
# 2     Bachelors/Family        1     NaN  Immediately          East
# 3     Bachelors/Family        1       1  Immediately           NaN
# 4     Bachelors/Family        1       1  Immediately           NaN
# ...                ...      ...     ...          ...           ...
# 2341  Bachelors/Family        3       3  Immediately  North - East
# 2342  Bachelors/Family        2       2  Immediately           NaN
# 2343         Bachelors        3       3  Immediately  North - East
# 2344            Family        2       2  Immediately          East
# 2345         Bachelors        1       1  Immediately         North
#
#                  overlooking        car parking owner resides curr_mark  \
# 0                        NaN                NaN           NaN         ₹
# 1     Garden/Park, Main Road  1 Covered, 1 Open           NaN         ₹
# 2                  Main Road             1 Open           NaN         ₹
# 3                        NaN                NaN           NaN         ₹
# 4                        NaN                NaN           NaN         ₹
# ...                      ...                ...           ...       ...
# 2341             Garden/Park          2 Covered  Same Premise         ₹
# 2342                     NaN                NaN           NaN         ₹
# 2343  Garden/Park, Main Road  1 Covered, 1 Open           NaN         ₹
# 2344               Main Road             1 Open           NaN         ₹
# 2345             Garden/Park             1 Open           NaN         ₹
#
#       hasLac  inr_pmo  usd_pmo                          point  \
# 0      False  10000.0   140.22                            NaN
# 1       True      1.6  2243.52  (31.8164399, 75.2218363, 0.0)
# 2      False   7000.0    98.15  (28.5070073, 77.1754171, 0.0)
# 3      False  20500.0   287.45                            NaN
# 4      False  13000.0   182.29                            NaN
# ...      ...      ...      ...                            ...
# 2341   False  64000.0   897.41                            NaN
# 2342   False  50000.0   701.10                            NaN
# 2343   False  63000.0   883.39                            NaN
# 2344   False  17500.0   245.38                            NaN
# 2345   False  10000.0   140.22                            NaN
#
#       longitude_right  latitude_right
# 0                 NaN             NaN
# 1           75.221836       31.816440
# 2           77.175417       28.507007
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 2341              NaN             NaN
# 2342              NaN             NaN
# 2343              NaN             NaN
# 2344              NaN             NaN
# 2345              NaN             NaN
#
# [2346 rows x 21 columns]

# %%
# Drop merge columns
tmp_df = tmp_df[tmp_df.columns.drop(['point', 'longitude_right', 'latitude_right'])]

# %%
tmp_df.rename(columns={'latitude_left':'latitude',
                       'longitude_left':'longitude'},
                       inplace=True)

# %%
# Check process
tmp_df
# Out:
#           price                                              title   latitude  \
# 0      ₹ 10,000              1 BHK Builder Floor for rent in Saket  28.523548
# 1     ₹ 1.6 Lac  4 BHK Builder Floor for rent in Greater Kailas...  31.816440
# 2       ₹ 7,000        1 BHK Builder Floor for rent in Chhattarpur  28.507007
# 3      ₹ 20,500  1 BHK House for rent in Dayanand Colony, Lajpa...  28.562599
# 4      ₹ 13,000       1 BHK Apartment for rent in Rohini Sector 18  28.741163
# ...         ...                                                ...        ...
# 2341   ₹ 64,000  3 BHK Builder Floor for rent in Sarvodaya Encl...  28.537321
# 2342   ₹ 50,000  2 BHK Builder Floor for rent in Vasant Vihar 4...  28.568102
# 2343   ₹ 63,000  3 BHK Builder Floor for rent in Safdarjung Enc...  28.563671
# 2344   ₹ 17,500  2 BHK Builder Floor for rent in Subhash Nagar ...  28.634584
# 2345   ₹ 10,000              2 BHK Apartment for rent in Vikaspuri  28.637766
#
#       longitude                   floor      furnishing tenants preferred  \
# 0     77.208893       2 out of 4 Floors       Furnished  Bachelors/Family
# 1     75.221836       2 out of 3 Floors  Semi-Furnished  Bachelors/Family
# 2     77.175417       2 out of 3 Floors  Semi-Furnished  Bachelors/Family
# 3     77.249603  Ground out of 3 Floors       Furnished  Bachelors/Family
# 4     77.134613       2 out of 4 Floors  Semi-Furnished  Bachelors/Family
# ...         ...                     ...             ...               ...
# 2341  77.203056       3 out of 4 Floors  Semi-Furnished  Bachelors/Family
# 2342  77.162636       2 out of 3 Floors     Unfurnished  Bachelors/Family
# 2343  77.190063       3 out of 3 Floors       Furnished         Bachelors
# 2344  77.049034       2 out of 3 Floors  Semi-Furnished            Family
# 2345  77.075966       1 out of 3 Floors  Semi-Furnished         Bachelors
#
#      bathroom balcony availability        facing             overlooking  \
# 0           2       1  Immediately           NaN                     NaN
# 1           4       2  Immediately         South  Garden/Park, Main Road
# 2           1     NaN  Immediately          East               Main Road
# 3           1       1  Immediately           NaN                     NaN
# 4           1       1  Immediately           NaN                     NaN
# ...       ...     ...          ...           ...                     ...
# 2341        3       3  Immediately  North - East             Garden/Park
# 2342        2       2  Immediately           NaN                     NaN
# 2343        3       3  Immediately  North - East  Garden/Park, Main Road
# 2344        2       2  Immediately          East               Main Road
# 2345        1       1  Immediately         North             Garden/Park
#
#             car parking owner resides curr_mark  hasLac  inr_pmo  usd_pmo
# 0                   NaN           NaN         ₹   False  10000.0   140.22
# 1     1 Covered, 1 Open           NaN         ₹    True      1.6  2243.52
# 2                1 Open           NaN         ₹   False   7000.0    98.15
# 3                   NaN           NaN         ₹   False  20500.0   287.45
# 4                   NaN           NaN         ₹   False  13000.0   182.29
# ...                 ...           ...       ...     ...      ...      ...
# 2341          2 Covered  Same Premise         ₹   False  64000.0   897.41
# 2342                NaN           NaN         ₹   False  50000.0   701.10
# 2343  1 Covered, 1 Open           NaN         ₹   False  63000.0   883.39
# 2344             1 Open           NaN         ₹   False  17500.0   245.38
# 2345             1 Open           NaN         ₹   False  10000.0   140.22
#
# [2346 rows x 18 columns]

# %%
round(tmp_df.isna().mean() * 100, 2)
# Out:
# price                 0.00
# title                 0.00
# latitude              8.27
# longitude             8.27
# floor                20.29
# furnishing           16.84
# tenants preferred    16.79
# bathroom             17.09
# balcony              30.05
# availability         16.79
# facing               36.62
# overlooking          40.79
# car parking          64.36
# owner resides        95.40
# curr_mark             0.00
# hasLac                0.00
# inr_pmo               3.07
# usd_pmo               3.07
# dtype: float64

# %%
# Serialize what I have got
tmp_df.to_csv('./cleaned.csv', encoding='utf-8', index=False)
