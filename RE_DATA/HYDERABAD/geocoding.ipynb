# %%
import re
import time
import numpy as np
import pandas as pd
import googlemaps as gmaps

gmaps = gmaps.Client(key='AIzaSyAiiG2SnCVLWlg0ZA6GKXS-beHPIidYVeM')

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()

# %%
df = pd.read_csv('data.csv')
print(df.shape)
df.head(5)
# Out:
# (2309, 14)
#       price                                              title  \
# 0  ₹ 18,000     3 BHK House for rent in Gudimalkapur 1400 sqft
# 1  ₹ 20,000       3 BHK Villa for rent in Shamshabad 1500 sqft
# 2   ₹ 5,800  1 BHK Apartment for rent in Vinayak Nagar II-H...
# 3  ₹ 14,000  2 BHK Apartment for rent in Kukatpally, NH 9 1...
# 4  ₹ 20,000     3 BHK Apartment for rent in Dellapur 1560 sqft
#
#        furnishing tenants preferred bathroom  availability  longitude  \
# 0     Unfurnished  Bachelors/Family        2   Immediately        NaN
# 1     Unfurnished         Bachelors        3  From Mar '20  17.270166
# 2     Unfurnished            Family        1   Immediately        NaN
# 3  Semi-Furnished  Bachelors/Family        2   Immediately        NaN
# 4  Semi-Furnished  Bachelors/Family        2   Immediately        NaN
#
#     latitude balcony              floor facing overlooking car parking  \
# 0        NaN     NaN                NaN    NaN         NaN         NaN
# 1  78.393593       3                NaN    NaN         NaN         NaN
# 2        NaN       1   1 out of 1 Floor   East   Main Road         NaN
# 3        NaN     NaN  2 out of 5 Floors    NaN         NaN         NaN
# 4        NaN     NaN  5 out of 5 Floors    NaN         NaN         NaN
#
#   owner resides
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
def parse_address(x):
    x = re.split(' \d\d+', x)[0]
    x = re.split(' in', x)[-1]
    return x+', Hyderabad'

# %%
df['address'] = df['title'].apply(parse_address)

# %%
print(len(df), 'total rows')
unique_locs = list(set(df['address']))
print(len(unique_locs), 'unique locations')
# Out:
# 2309 total rows
# 863 unique locations

# %% [markdown]
# # Geocoding

# %%
def get_gmap_geos(locations, max_errors=10):
    geocoded = dict()
    start_time = time.perf_counter()
    errors = 0
    for iteration, location in enumerate(locations):
        try:
            geocoded[location] = gmaps.geocode(location)
            time.sleep(.05) # <-- throttle
        except:
            time.sleep(2)
            try:
                geocoded[location] = gmaps.geocode(location)
            except:
                time.sleep(2)
                try:
                    geocoded[location] = gmaps.geocode(location)
                except:
                    geocoded[location] = 'error'
                    errors+=1
        if errors>max_errors:
            print('stopped at', iteration, '(max errors reached)')
            break
            return geocoded
        if iteration>0 and iteration%200==0:
            now = time.strftime('%H:%M:%S', time.localtime(time.time()))
            print(f'{now} | {iteration} locations geocoded ({round(iteration/len(unique_locs)*100, 2)}%) | {errors} total errors')
    print(f'job completed in {time.perf_counter() - start_time}s\n{errors} requests timed out')
    print(len([v for v in geocoded.values() if v=='error']), 'locations not found')
    return geocoded

# %%
unique_geocodes = get_gmap_geos(unique_locs)
# Out:
# 21:37:59 | 200 locations geocoded (23.17%) | 0 total errors
# 21:39:43 | 400 locations geocoded (46.35%) | 0 total errors
# 21:41:24 | 600 locations geocoded (69.52%) | 0 total errors
# 21:43:18 | 800 locations geocoded (92.7%) | 0 total errors
# job completed in 454.48432708099995s
# 0 requests timed out
# 0 locations not found

# %% [markdown]
# ### Map back onto df

# %%
unique_geocodes
# Out:
# {' RV Citin Loft, Manikonda, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': 'Road Number 25',
#      'short_name': 'Rd Number 25',
#      'types': ['route']},
#     {'long_name': 'Huda',
#      'short_name': 'Huda',
#      'types': ['political', 'sublocality', 'sublocality_level_3']},
#     {'long_name': 'Alkapur Township',
#      'short_name': 'Alkapur Twp',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Manikonda',
#      'short_name': 'Manikonda',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500075', 'short_name': '500075', 'types': ['postal_code']}],
#    'formatted_address': 'Rd Number 25, Huda, Alkapur Twp, Manikonda, Hyderabad, Telangana 500075, India',
#    'geometry': {'location': {'lat': 17.3890934, 'lng': 78.37217629999999},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.39044238029151,
#       'lng': 78.3735252802915},
#      'southwest': {'lat': 17.3877444197085, 'lng': 78.3708273197085}}},
#    'place_id': 'ChIJQ4V61zqUyzsR2A_kYKRCN5s',
#    'plus_code': {'compound_code': '99QC+JV Hyderabad, Telangana, India',
#     'global_code': '7J9W99QC+JV'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Kutbi Guda, Kachiguda, NH 2 2, Hyderabad': [{'address_components': [{'long_name': 'Kutbi Guda',
#      'short_name': 'Kutbi Guda',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Kachiguda',
#      'short_name': 'Kachiguda',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Kutbi Guda, Kachiguda, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.390561, 'lng': 78.493355},
#      'southwest': {'lat': 17.3837501, 'lng': 78.4876331}},
#     'location': {'lat': 17.3867353, 'lng': 78.4901118},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.390561, 'lng': 78.493355},
#      'southwest': {'lat': 17.3837501, 'lng': 78.4876331}}},
#    'partial_match': True,
#    'place_id': 'ChIJ4RBtZM6ZyzsRrzdQMxx5AfQ',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}],
#  ' Suraram, Hyderabad': [{'address_components': [{'long_name': 'Suraram',
#      'short_name': 'Suraram',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Suraram, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.5636291,
#       'lng': 78.46671309999999},
#      'southwest': {'lat': 17.523602, 'lng': 78.41084099999999}},
#     'location': {'lat': 17.5412112, 'lng': 78.43384809999999},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.5636291, 'lng': 78.46671309999999},
#      'southwest': {'lat': 17.523602, 'lng': 78.41084099999999}}},
#    'place_id': 'ChIJW9bkk7WPyzsRjbLeoVdxyTs',
#    'types': ['political', 'sublocality', 'sublocality_level_1']}],
#  ' Rolling Hills, Gachibowli, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': 'Nehru Outer Ring Road',
#      'short_name': 'Nehru Outer Ring Rd',
#      'types': ['route']},
#     {'long_name': 'Gachibowli',
#      'short_name': 'Gachibowli',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Nehru Outer Ring Rd, Gachibowli, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4385862, 'lng': 78.3637078},
#      'southwest': {'lat': 17.4179337, 'lng': 78.35595359999999}},
#     'location': {'lat': 17.4285994, 'lng': 78.3588692},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4385862, 'lng': 78.3637078},
#      'southwest': {'lat': 17.4179337, 'lng': 78.35595359999999}}},
#    'place_id': 'EjxOZWhydSBPdXRlciBSaW5nIFJkLCBHYWNoaWJvd2xpLCBIeWRlcmFiYWQsIFRlbGFuZ2FuYSwgSW5kaWEiLiosChQKEgnXu6E9TXXLOxH8vLSE8JTABhIUChIJ387edqKTyzsR4kSTb57nEiw',
#    'types': ['route']}],
#  ' Omsree Patels Green Park, Yapral, Hyderabad': [{'address_components': [{'long_name': "Patel's Green Front",
#      'short_name': "Patel's Green Front",
#      'types': []},
#     {'long_name': 'Maherr Road',
#      'short_name': 'Maherr Road',
#      'types': ['route']},
#     {'long_name': 'Jai Jawahar Nagar',
#      'short_name': 'Jai Jawahar Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Yapral',
#      'short_name': 'Yapral',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Secunderabad',
#      'short_name': 'SC',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500087', 'short_name': '500087', 'types': ['postal_code']}],
#    'formatted_address': "Maherr Road, near Patel's Green Front, Jai Jawahar Nagar, Yapral, Secunderabad, Telangana 500087, India",
#    'geometry': {'location': {'lat': 17.5069056, 'lng': 78.5366313},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.5082545802915,
#       'lng': 78.53798028029149},
#      'southwest': {'lat': 17.5055566197085, 'lng': 78.53528231970849}}},
#    'place_id': 'ChIJ7VAECzybyzsRYvdEcavFOkU',
#    'plus_code': {'compound_code': 'GG4P+QM Yapral, Secunderabad, Telangana, India',
#     'global_code': '7J9WGG4P+QM'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Manikonda, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': 'Nehru Outer Ring Road',
#      'short_name': 'Nehru Outer Ring Rd',
#      'types': ['route']},
#     {'long_name': 'Manikonda',
#      'short_name': 'Manikonda',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Nehru Outer Ring Rd, Manikonda, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4314943, 'lng': 78.3596761},
#      'southwest': {'lat': 17.3990842, 'lng': 78.3520114}},
#     'location': {'lat': 17.4153172, 'lng': 78.3556287},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4314943, 'lng': 78.3596761},
#      'southwest': {'lat': 17.3990842, 'lng': 78.3520114}}},
#    'place_id': 'EjtOZWhydSBPdXRlciBSaW5nIFJkLCBNYW5pa29uZGEsIEh5ZGVyYWJhZCwgVGVsYW5nYW5hLCBJbmRpYSIuKiwKFAoSCde7oT1Ndcs7Efy8tITwlMAGEhQKEgn3sy9TIpTLOxHxKi490PqTxw',
#    'types': ['route']}],
#  ' Dabeerpura, Hyderabad': [{'address_components': [{'long_name': 'Dabeerpura',
#      'short_name': 'Dabeerpura',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500023', 'short_name': '500023', 'types': ['postal_code']}],
#    'formatted_address': 'Dabeerpura, Hyderabad, Telangana 500023, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.3678571,
#       'lng': 78.49789609999999},
#      'southwest': {'lat': 17.360836, 'lng': 78.48411279999999}},
#     'location': {'lat': 17.3655876, 'lng': 78.485669},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.3678571, 'lng': 78.49789609999999},
#      'southwest': {'lat': 17.360836, 'lng': 78.48411279999999}}},
#    'place_id': 'ChIJjRrfJDqYyzsRzBErFKK7MJ8',
#    'types': ['political', 'sublocality', 'sublocality_level_1']}],
#  ' Madhava Nagar Colony, Miyapur, Hyderabad': [{'address_components': [{'long_name': 'Madhava Nagar Colony',
#      'short_name': 'Madhava Nagar Colony',
#      'types': ['political', 'sublocality', 'sublocality_level_3']},
#     {'long_name': 'Ambedkar Nagar',
#      'short_name': 'Ambedkar Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Hafeezpet',
#      'short_name': 'Hafeezpet',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500049', 'short_name': '500049', 'types': ['postal_code']}],
#    'formatted_address': 'Madhava Nagar Colony, Ambedkar Nagar, Hafeezpet, Hyderabad, Telangana 500049, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4967689, 'lng': 78.363165},
#      'southwest': {'lat': 17.4934139, 'lng': 78.359729}},
#     'location': {'lat': 17.4952899, 'lng': 78.3611116},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.4967689, 'lng': 78.363165},
#      'southwest': {'lat': 17.4934139, 'lng': 78.359729}}},
#    'place_id': 'ChIJ_y7SSmuSyzsRAm-DXm2ImWs',
#    'types': ['political', 'sublocality', 'sublocality_level_3']}],
#  ' Valmiki Nagar-Domalguda, NH 7, Hyderabad': [{'address_components': [{'long_name': 'National Highway 44',
#      'short_name': 'NH 44',
#      'types': ['route']},
#     {'long_name': 'Valmiki Nagar',
#      'short_name': 'Valmiki Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_3']},
#     {'long_name': 'Domalguda',
#      'short_name': 'Domalguda',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Himayatnagar',
#      'short_name': 'Himayatnagar',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'NH 44, Valmiki Nagar, Domalguda, Himayatnagar, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4132984,
#       'lng': 78.47829089999999},
#      'southwest': {'lat': 17.4101357, 'lng': 78.47611239999999}},
#     'location': {'lat': 17.411836, 'lng': 78.47727040000001},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4139188, 'lng': 78.47935319999999},
#      'southwest': {'lat': 17.4097532, 'lng': 78.47518760000001}}},
#    'place_id': 'EkpOSCA0NCwgVmFsbWlraSBOYWdhciwgRG9tYWxndWRhLCBIaW1heWF0bmFnYXIsIEh5ZGVyYWJhZCwgVGVsYW5nYW5hLCBJbmRpYSIuKiwKFAoSCVXiJOE8xo85EYzKi4BjhIWUEhQKEgkTN5jx45nLOxHd3qwXUyBIUw',
#    'types': ['route']}],
#  ' Senthan Greenpark, Beeramguda, Ramachandra Puram, NH 9, Hyderabad': [{'address_components': [{'long_name': 'Ameenpur',
#      'short_name': 'Ameenpur',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Senthan Green Park',
#      'short_name': 'Senthan Green Park',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Ramachandra Puram',
#      'short_name': 'Ramachandra Puram',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Medak',
#      'short_name': 'Medak',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '502032', 'short_name': '502032', 'types': ['postal_code']}],
#    'formatted_address': 'Senthan Green Park, Ameenpur, Ramachandra Puram, Hyderabad, Telangana 502032, India',
#    'geometry': {'location': {'lat': 17.5325226, 'lng': 78.3103464},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.5338715802915,
#       'lng': 78.31169538029151},
#      'southwest': {'lat': 17.5311736197085, 'lng': 78.30899741970849}}},
#    'place_id': 'ChIJiQLqSEeNyzsRtAHXfu7OkJo',
#    'plus_code': {'compound_code': 'G8M6+24 Ramachandra Puram, Hyderabad, Telangana, India',
#     'global_code': '7J9WG8M6+24'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Pasha Colony, Ibrahim Bagh, Hyderabad': [{'address_components': [{'long_name': 'Pasha Colony',
#      'short_name': 'Pasha Colony',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'CEO Enclave',
#      'short_name': 'CEO Enclave',
#      'types': ['political', 'sublocality', 'sublocality_level_3']},
#     {'long_name': 'Ibrahim Bagh',
#      'short_name': 'Ibrahim Bagh',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500075', 'short_name': '500075', 'types': ['postal_code']}],
#    'formatted_address': 'CEO Enclave, Pasha Colony, Ibrahim Bagh, Hyderabad, Telangana 500075, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.394849, 'lng': 78.388274},
#      'southwest': {'lat': 17.3913611, 'lng': 78.38057289999999}},
#     'location': {'lat': 17.3936156, 'lng': 78.3835117},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.394849, 'lng': 78.388274},
#      'southwest': {'lat': 17.3913611, 'lng': 78.38057289999999}}},
#    'place_id': 'ChIJjx78AJ6WyzsRhW85niw7zQY',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}],
#  ' Pranit Mayfair Villas, Gachibowli, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': "Vision's Infiniti Homes",
#      'short_name': "Vision's Infiniti Homes",
#      'types': ['premise']},
#     {'long_name': 'Tellapur-Osman Nagar Road',
#      'short_name': 'Tellapur-Osman Nagar Rd',
#      'types': ['route']},
#     {'long_name': 'Tellapur',
#      'short_name': 'Tellapur',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Medak',
#      'short_name': 'Medak',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500019', 'short_name': '500019', 'types': ['postal_code']}],
#    'formatted_address': "Tellapur-Osman Nagar Rd, opp. Vision's Infiniti Homes, Tellapur, Hyderabad, Telangana 500019, India",
#    'geometry': {'location': {'lat': 17.4535388, 'lng': 78.2909004},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4548877802915,
#       'lng': 78.29224938029151},
#      'southwest': {'lat': 17.4521898197085, 'lng': 78.2895514197085}}},
#    'place_id': 'ChIJA6fn3ePtyzsRKwIhnhw6y1w',
#    'plus_code': {'compound_code': 'F73R+C9 Tellapur, Hyderabad, Telangana, India',
#     'global_code': '7J9WF73R+C9'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' New Bowenpally, NH 7, Hyderabad': [{'address_components': [{'long_name': 'National Highway 44',
#      'short_name': 'NH 44',
#      'types': ['route']},
#     {'long_name': 'New Bowenpally',
#      'short_name': 'New Bowenpally',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Bowenpally',
#      'short_name': 'Bowenpally',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Secunderabad',
#      'short_name': 'SC',
#      'types': ['locality', 'political']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'NH 44, New Bowenpally, Bowenpally, Secunderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4677687, 'lng': 78.4858051},
#      'southwest': {'lat': 17.4538006, 'lng': 78.4725081}},
#     'location': {'lat': 17.4588159, 'lng': 78.4773342},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4661726, 'lng': 78.48469089999999},
#      'southwest': {'lat': 17.4514592, 'lng': 78.4699775}}},
#    'place_id': 'EkFOSCA0NCwgTmV3IEJvd2VucGFsbHksIEJvd2VucGFsbHksIFNlY3VuZGVyYWJhZCwgVGVsYW5nYW5hLCBJbmRpYSIuKiwKFAoSCVXiJOE8xo85EYzKi4BjhIWUEhQKEglbzFMDeJrLOxFhX5Vt6-cbeg',
#    'types': ['route']}],
#  ' Balapur, Hyderabad': [{'address_components': [{'long_name': 'Balapur',
#      'short_name': 'Balapur',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Balapur, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.319236,
#       'lng': 78.52296009999999},
#      'southwest': {'lat': 17.282995, 'lng': 78.48452590000001}},
#     'location': {'lat': 17.3088602, 'lng': 78.50623619999999},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.319236, 'lng': 78.52296009999999},
#      'southwest': {'lat': 17.282995, 'lng': 78.48452590000001}}},
#    'place_id': 'ChIJnx0TtOSiyzsRO4qPUZyJ6i4',
#    'types': ['political', 'sublocality', 'sublocality_level_1']}],
#  ' Star Homes, Balanagar, Hyderabad': [{'address_components': [{'long_name': 'Gandhi Nagar Road',
#      'short_name': 'Gandhi Nagar Rd',
#      'types': ['route']},
#     {'long_name': 'Nanda Nagar',
#      'short_name': 'Nanda Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Balanagar',
#      'short_name': 'Balanagar',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500055', 'short_name': '500055', 'types': ['postal_code']}],
#    'formatted_address': 'Gandhi Nagar Rd, Nanda Nagar, Balanagar, Hyderabad, Telangana 500055, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4932747, 'lng': 78.4456387},
#      'southwest': {'lat': 17.4928697, 'lng': 78.4445411}},
#     'location': {'lat': 17.4930839, 'lng': 78.44504239999999},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4944211802915,
#       'lng': 78.44643888029151},
#      'southwest': {'lat': 17.4917232197085, 'lng': 78.4437409197085}}},
#    'place_id': 'ChIJ7zQcI0eQyzsRMOaDB770Gc0',
#    'types': ['establishment', 'premise']}],
#  ' Shanti Nagar Colony, Patancheru, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': 'Nehru Outer Ring Road',
#      'short_name': 'Nehru Outer Ring Rd',
#      'types': ['route']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Nehru Outer Ring Rd, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.6191267, 'lng': 78.7022678},
#      'southwest': {'lat': 17.1892488, 'lng': 78.2020387}},
#     'location': {'lat': 17.4384109, 'lng': 78.36367179999999},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.6191267, 'lng': 78.7022678},
#      'southwest': {'lat': 17.1892488, 'lng': 78.2020387}}},
#    'place_id': 'EiVOZWhydSBPdXRlciBSaW5nIFJkLCBUZWxhbmdhbmEsIEluZGlhIi4qLAoUChIJ17uhPU11yzsR_Ly0hPCUwAYSFAoSCbFHMhuU8ss7EdxY0OJW5s0o',
#    'types': ['route']}],
#  ' Balanagar, Hyderabad': [{'address_components': [{'long_name': 'Balanagar',
#      'short_name': 'Balanagar',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Balanagar, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.497409, 'lng': 78.472991},
#      'southwest': {'lat': 17.4544581, 'lng': 78.4265255}},
#     'location': {'lat': 17.4813993, 'lng': 78.44899350000001},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.497409, 'lng': 78.472991},
#      'southwest': {'lat': 17.4544581, 'lng': 78.4265255}}},
#    'place_id': 'ChIJU7FjafaQyzsRHJQ8M0aR5XU',
#    'types': ['political', 'sublocality', 'sublocality_level_1']}],
#  ' Rainbow Vistas, Hitech City, Hyderabad': [{'address_components': [{'long_name': 'IDL',
#      'short_name': 'IDL',
#      'types': []},
#     {'long_name': 'Sevalal Nagar',
#      'short_name': 'Sevalal Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Borabanda',
#      'short_name': 'Borabanda',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500018', 'short_name': '500018', 'types': ['postal_code']}],
#    'formatted_address': 'Cybercity, Hariram Hills, Green Hills Road Moosapet Kukatpally Road Near, Hitech City MMTS, Opposite IDL, Sevalal Nagar, Borabanda, Hyderabad, Telangana 500018, India',
#    'geometry': {'location': {'lat': 17.4677481, 'lng': 78.4081475},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4690970802915,
#       'lng': 78.40949648029151},
#      'southwest': {'lat': 17.46639911970849, 'lng': 78.40679851970849}}},
#    'place_id': 'ChIJr2DFqKaRyzsR7aPvpwuPsRE',
#    'plus_code': {'compound_code': 'FC95+37 Hyderabad, Telangana, India',
#     'global_code': '7J9WFC95+37'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Aditya Imperial Heights, Hafeezpet, NH 9, Hyderabad': [{'address_components': [{'long_name': 'Manjeera Pipeline Road',
#      'short_name': 'Manjeera Pipeline Rd',
#      'types': ['route']},
#     {'long_name': 'APGOs Coop HSG Society',
#      'short_name': 'APGOs Coop HSG Society',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Hafeezpet',
#      'short_name': 'Hafeezpet',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500084', 'short_name': '500084', 'types': ['postal_code']}],
#    'formatted_address': 'Manjeera Pipeline Rd, APGOs Coop HSG Society, Hafeezpet, Hyderabad, Telangana 500084, India',
#    'geometry': {'location': {'lat': 17.4840305, 'lng': 78.35881049999999},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 17.4853794802915,
#       'lng': 78.3601594802915},
#      'southwest': {'lat': 17.4826815197085, 'lng': 78.35746151970848}}},
#    'place_id': 'ChIJqSv_KEeSyzsR55hwWqLaYRA',
#    'plus_code': {'compound_code': 'F9M5+JG Hyderabad, Telangana, India',
#     'global_code': '7J9WF9M5+JG'},
#    'types': ['establishment', 'premise']}],
#  ' Ameenapur, Hyderabad': [{'address_components': [{'long_name': 'Ameenpur',
#      'short_name': 'Ameenpur',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Miyapur',
#      'short_name': 'Miyapur',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Ameenpur, Miyapur, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.5481221, 'lng': 78.357556},
#      'southwest': {'lat': 17.5084819, 'lng': 78.31082}},
#     'location': {'lat': 17.5171428, 'lng': 78.315742},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.5481221, 'lng': 78.357556},
#      'southwest': {'lat': 17.5084819, 'lng': 78.31082}}},
#    'place_id': 'ChIJ5yuyN2-NyzsRsrew1Uqs2f0',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}],
#  ' Patancheru Mandal, Hyderabad': [{'address_components': [{'long_name': 'Sri Nagar Colony',
#      'short_name': 'Sri Nagar Colony',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Patancheru',
#      'short_name': 'Patancheru',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Medak',
#      'short_name': 'Medak',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '502319', 'short_name': '502319', 'types': ['postal_code']}],
#    'formatted_address': 'Sri Nagar Colony, Patancheru, Hyderabad, Telangana 502319, India',
#    'geometry': {'location': {'lat': 17.5264657, 'lng': 78.2674622},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.5278146802915,
#       'lng': 78.26881118029151},
#      'southwest': {'lat': 17.5251167197085, 'lng': 78.2661132197085}}},
#    'place_id': 'ChIJ2wiCSzbzyzsRbg5-Wh-KOUs',
#    'plus_code': {'compound_code': 'G7G8+HX Hyderabad, Telangana, India',
#     'global_code': '7J9WG7G8+HX'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Annojiguda, NH 2 2, Hyderabad': [{'address_components': [{'long_name': 'Gachibowli',
#      'short_name': 'Gachibowli',
#      'types': ['route']},
#     {'long_name': 'Rahmat Gulshan Colony',
#      'short_name': 'Rahmat Gulshan Colony',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'P Janardhan Reddy Nagar',
#      'short_name': 'P Janardhan Reddy Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Gachibowli',
#      'short_name': 'Gachibowli',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500032', 'short_name': '500032', 'types': ['postal_code']}],
#    'formatted_address': 'Gachibowli, Rahmat Gulshan Colony, P Janardhan Reddy Nagar, Gachibowli, Hyderabad, Telangana 500032, India',
#    'geometry': {'location': {'lat': 17.439055, 'lng': 78.363964},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4404039802915,
#       'lng': 78.3653129802915},
#      'southwest': {'lat': 17.4377060197085, 'lng': 78.3626150197085}}},
#    'place_id': 'ChIJfxtVd-uTyzsR1eirm2rgJCg',
#    'plus_code': {'compound_code': 'C9Q7+JH Gachibowli, Hyderabad, Telangana, India',
#     'global_code': '7J9WC9Q7+JH'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' JPR Enclave, Balanagar, Hyderabad': [{'address_components': [{'long_name': 'JPR Enclave',
#      'short_name': 'JPR Enclave',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Balanagar',
#      'short_name': 'Balanagar',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500042', 'short_name': '500042', 'types': ['postal_code']}],
#    'formatted_address': 'JPR Enclave, Balanagar, Hyderabad, Telangana 500042, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.47946, 'lng': 78.4625489},
#      'southwest': {'lat': 17.474227, 'lng': 78.456447}},
#     'location': {'lat': 17.476728, 'lng': 78.4602749},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.47946, 'lng': 78.4625489},
#      'southwest': {'lat': 17.474227, 'lng': 78.456447}}},
#    'place_id': 'ChIJL7GM9GSQyzsR8g35zmVUZm4',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}],
#  ' Jains Carlton Creek, Gachibowli, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': 'Public School',
#      'short_name': 'Public School',
#      'types': ['premise']},
#     {'long_name': 'Lanco Hills Road',
#      'short_name': 'Lanco Hills Rd',
#      'types': ['route']},
#     {'long_name': 'Sai Vaibhav Layout',
#      'short_name': 'Sai Vaibhav Layout',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Sai Aishwarya Layout',
#      'short_name': 'Sai Aishwarya Layout',
#      'types': ['political', 'sublocality', 'sublocality_level_3']},
#     {'long_name': 'Khajaguda',
#      'short_name': 'Khajaguda',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Manikonda',
#      'short_name': 'Manikonda',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500089', 'short_name': '500089', 'types': ['postal_code']}],
#    'formatted_address': 'Besides Delhi, Public School, Lanco Hills Rd, Sai Vaibhav Layout, Sai Aishwarya Layout, Khajaguda, Manikonda, Hyderabad, Telangana 500089, India',
#    'geometry': {'location': {'lat': 17.4162768, 'lng': 78.37000139999999},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 17.4176257802915,
#       'lng': 78.3713503802915},
#      'southwest': {'lat': 17.4149278197085, 'lng': 78.36865241970848}}},
#    'place_id': 'ChIJZ087JAmUyzsRO8dh8wEvaZw',
#    'plus_code': {'compound_code': 'C98C+G2 Manikonda, Hyderabad, Telangana, India',
#     'global_code': '7J9WC98C+G2'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Fort View Colony, Hyderabad': [{'address_components': [{'long_name': 'Fort View Colony',
#      'short_name': 'Fort View Colony',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Upparpally',
#      'short_name': 'Upparpally',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500030', 'short_name': '500030', 'types': ['postal_code']}],
#    'formatted_address': 'Fort View Colony, Upparpally, Hyderabad, Telangana 500030, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.3560111, 'lng': 78.4186521},
#      'southwest': {'lat': 17.3518509, 'lng': 78.41500900000001}},
#     'location': {'lat': 17.3537475, 'lng': 78.4172804},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.3560111, 'lng': 78.4186521},
#      'southwest': {'lat': 17.3518509, 'lng': 78.41500900000001}}},
#    'place_id': 'ChIJf8AYdTiWyzsRX_zAu8V-dM8',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}],
#  ' Surya Balram Enclave, Alwal, Hyderabad': [{'address_components': [{'long_name': 'Surya Balaram Enclave',
#      'short_name': 'Surya Balaram Enclave',
#      'types': ['political', 'sublocality', 'sublocality_level_3']},
#     {'long_name': 'Prasanthi Nagar Colony',
#      'short_name': 'Prasanthi Nagar Colony',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Alwal',
#      'short_name': 'Alwal',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Secunderabad',
#      'short_name': 'SC',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500010', 'short_name': '500010', 'types': ['postal_code']}],
#    'formatted_address': 'Surya Balaram Enclave, Prasanthi Nagar Colony, Alwal, Secunderabad, Telangana 500010, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.5076051, 'lng': 78.5070099},
#      'southwest': {'lat': 17.5065979, 'lng': 78.5055141}},
#     'location': {'lat': 17.5071831, 'lng': 78.50635849999999},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.5084504802915,
#       'lng': 78.50761098029152},
#      'southwest': {'lat': 17.5057525197085, 'lng': 78.5049130197085}}},
#    'place_id': 'ChIJ-xB_V8SayzsRHN7MAdCEuX8',
#    'types': ['political', 'sublocality', 'sublocality_level_3']}],
#  ' Manjeera Trinity Homes, Kukatpally, NH 9, Hyderabad': [{'address_components': [{'long_name': 'KPHB Phase III',
#      'short_name': 'KPHB Phase III',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'K P H B Phase 3',
#      'short_name': 'K P H B Phase 3',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Kukatpally Housing Board',
#      'short_name': 'Kukatpally Housing Board',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500072', 'short_name': '500072', 'types': ['postal_code']}],
#    'formatted_address': 'KPHB Phase III, K P H B Phase 3, Kukatpally Housing Board, Hyderabad, Telangana 500072, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4901221, 'lng': 78.3940138},
#      'southwest': {'lat': 17.4893904, 'lng': 78.3935175}},
#     'location': {'lat': 17.4896602, 'lng': 78.3937323},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 17.4911052302915,
#       'lng': 78.3951146302915},
#      'southwest': {'lat': 17.4884072697085, 'lng': 78.3924166697085}}},
#    'partial_match': True,
#    'place_id': 'ChIJ8VJHCI2RyzsR-M5_1PKCA0c',
#    'types': ['establishment', 'premise']}],
#  ' Aparna Infra Housing Apartments, Gachibowli, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': 'Nanakramguda',
#      'short_name': 'Nanakramguda',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Maqtha Kousarali',
#      'short_name': 'Maqtha Kousarali',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500032', 'short_name': '500032', 'types': ['postal_code']}],
#    'formatted_address': 'Nanakramguda, Maqtha Kousarali, Telangana 500032, India',
#    'geometry': {'location': {'lat': 17.4193857, 'lng': 78.35328489999999},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4207346802915,
#       'lng': 78.35463388029149},
#      'southwest': {'lat': 17.4180367197085, 'lng': 78.35193591970848}}},
#    'place_id': 'ChIJY70gMnaUyzsR4gl6DtNbTzk',
#    'plus_code': {'compound_code': 'C993+Q8 Hyderabad, Telangana, India',
#     'global_code': '7J9WC993+Q8'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Metro Classic, A C Guards, Lakdikapul, NH 9, Hyderabad': [{'address_components': [{'long_name': 'AC Guards Road',
#      'short_name': 'AC Guards Rd',
#      'types': ['route']},
#     {'long_name': 'AC Guards',
#      'short_name': 'AC Guards',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Masab Tank',
#      'short_name': 'Masab Tank',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500004', 'short_name': '500004', 'types': ['postal_code']}],
#    'formatted_address': 'AC Guards Rd, AC Guards, Masab Tank, Hyderabad, Telangana 500004, India',
#    'geometry': {'location': {'lat': 17.3988795, 'lng': 78.45927689999999},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4002284802915,
#       'lng': 78.4606258802915},
#      'southwest': {'lat': 17.3975305197085, 'lng': 78.4579279197085}}},
#    'place_id': 'ChIJB7RAammXyzsR9SporfPBejo',
#    'plus_code': {'compound_code': '9FX5+HP Hyderabad, Telangana, India',
#     'global_code': '7J9W9FX5+HP'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Laxminagar Colony, Saroornagar, Hyderabad': [{'address_components': [{'long_name': 'Laxminagar Colony',
#      'short_name': 'Laxminagar Colony',
#      'types': ['political', 'sublocality', 'sublocality_level_3']},
#     {'long_name': 'Saidabad',
#      'short_name': 'Saidabad',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500059', 'short_name': '500059', 'types': ['postal_code']}],
#    'formatted_address': 'Laxminagar Colony, Saidabad, Hyderabad, Telangana 500059, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.3577231,
#       'lng': 78.51490009999999},
#      'southwest': {'lat': 17.351888, 'lng': 78.51118799999999}},
#     'location': {'lat': 17.3545693, 'lng': 78.5128388},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.3577231, 'lng': 78.51490009999999},
#      'southwest': {'lat': 17.351888, 'lng': 78.51118799999999}}},
#    'place_id': 'ChIJgRJ1VmaYyzsRxYoqLpDKoe0',
#    'types': ['political', 'sublocality', 'sublocality_level_3']}],
#  ' Lanco Hills, Manikonda, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': 'Manikonda',
#      'short_name': 'Manikonda',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500089', 'short_name': '500089', 'types': ['postal_code']}],
#    'formatted_address': '99LH Lanco Hills, Gachibowli, Manikonda, Hyderabad, Telangana 500089, India',
#    'geometry': {'location': {'lat': 17.4082259, 'lng': 78.3743967},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4095748802915,
#       'lng': 78.37574568029152},
#      'southwest': {'lat': 17.4068769197085, 'lng': 78.37304771970851}}},
#    'place_id': 'ChIJ-yqCQBmUyzsRlQSc7r6he6c',
#    'plus_code': {'compound_code': 'C95F+7Q Manikonda, Hyderabad, Telangana, India',
#     'global_code': '7J9WC95F+7Q'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Nekanampur, Hyderabad': [{'address_components': [{'long_name': 'Neknampur',
#      'short_name': 'Neknampur',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Manikonda',
#      'short_name': 'Manikonda',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Neknampur, Manikonda, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.396686,
#       'lng': 78.38459580000001},
#      'southwest': {'lat': 17.3827979, 'lng': 78.36798809999999}},
#     'location': {'lat': 17.3906569, 'lng': 78.3752624},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.396686, 'lng': 78.38459580000001},
#      'southwest': {'lat': 17.3827979, 'lng': 78.36798809999999}}},
#    'place_id': 'ChIJ53ehlySUyzsRreZv6_GbUfg',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}],
#  ' My Home Avatar, Near Narsingi cross roads, Hyderabad': [{'address_components': [{'long_name': 'Puppalaguda',
#      'short_name': 'Puppalaguda',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'DLF New Heights Gachibowli Extension',
#      'short_name': 'DLF New Heights Gachibowli Extension',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
# ...
#      'short_name': 'Serilingampally',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500084', 'short_name': '500084', 'types': ['postal_code']}],
#    'formatted_address': 'Maruthi Nivas, Sudarshan Nagar Colony, Serilingampally, Hyderabad, Telangana 500084, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4700973, 'lng': 78.3335804},
#      'southwest': {'lat': 17.4700016, 'lng': 78.3334543}},
#     'location': {'lat': 17.4700585, 'lng': 78.3335159},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 17.4713984302915,
#       'lng': 78.3348663302915},
#      'southwest': {'lat': 17.4687004697085, 'lng': 78.33216836970848}}},
#    'place_id': 'ChIJbWlhov6SyzsRvLsDSjYX1oc',
#    'types': ['premise']}],
#  ' Laharis Fort View, Attapur, Hyderabad': [{'address_components': [{'long_name': '3-3-107',
#      'short_name': '3-3-107',
#      'types': ['premise']},
#     {'long_name': 'Siri Enclave Colony',
#      'short_name': 'Siri Enclave Colony',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Jana Priya Utopia',
#      'short_name': 'Jana Priya Utopia',
#      'types': ['political', 'sublocality', 'sublocality_level_3']},
#     {'long_name': 'Upparpally',
#      'short_name': 'Upparpally',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500048', 'short_name': '500048', 'types': ['postal_code']}],
#    'formatted_address': '3-3-107, Siri Enclave Colony, Jana Priya Utopia, Upparpally, Hyderabad, Telangana 500048, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.3678675, 'lng': 78.4187216},
#      'southwest': {'lat': 17.3675385, 'lng': 78.4181892}},
#     'location': {'lat': 17.3677323, 'lng': 78.41843539999999},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 17.3690519802915,
#       'lng': 78.4198043802915},
#      'southwest': {'lat': 17.3663540197085, 'lng': 78.41710641970849}}},
#    'place_id': 'ChIJdUKSnVqWyzsRZXbzE-GQROc',
#    'types': ['establishment', 'premise']}],
#  ' Riddhis Valentino, Kondapur, Hyderabad': [{'address_components': [{'long_name': 'KMR Estates',
#      'short_name': 'KMR Estates',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Serilingampally',
#      'short_name': 'Serilingampally',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500084', 'short_name': '500084', 'types': ['postal_code']}],
#    'formatted_address': '500084, KMR Estates, Serilingampally, Hyderabad, Telangana 500084, India',
#    'geometry': {'location': {'lat': 17.4744312, 'lng': 78.3442247},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4757801802915,
#       'lng': 78.3455736802915},
#      'southwest': {'lat': 17.47308221970849, 'lng': 78.34287571970849}}},
#    'place_id': 'ChIJN2FhLFGSyzsRj3u4Q19CeWk',
#    'plus_code': {'compound_code': 'F8FV+QM Hyderabad, Telangana, India',
#     'global_code': '7J9WF8FV+QM'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' parimulgherry, Hyderabad': [{'address_components': [{'long_name': 'Trimulgherry',
#      'short_name': 'Trimulgherry',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Secunderabad',
#      'short_name': 'SC',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Trimulgherry, Secunderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.498843, 'lng': 78.532922},
#      'southwest': {'lat': 17.456461, 'lng': 78.4948216}},
#     'location': {'lat': 17.4777385, 'lng': 78.510745},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.498843, 'lng': 78.532922},
#      'southwest': {'lat': 17.456461, 'lng': 78.4948216}}},
#    'partial_match': True,
#    'place_id': 'ChIJf4MimleayzsRcG4t_s58s-4',
#    'types': ['political', 'sublocality', 'sublocality_level_1']}],
#  ' Telangana NGOS Colony, Katedan Industrial Area, Hyderabad': [{'address_components': [{'long_name': 'Telangana NGOS Colony',
#      'short_name': 'Telangana NGOS Colony',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Katedan Industrial Area',
#      'short_name': 'Katedan Industrial Area',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Telangana NGOS Colony, Katedan Industrial Area, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.31441,
#       'lng': 78.44550699999999},
#      'southwest': {'lat': 17.300326, 'lng': 78.4230681}},
#     'location': {'lat': 17.3070604, 'lng': 78.43398289999999},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.31441, 'lng': 78.44550699999999},
#      'southwest': {'lat': 17.300326, 'lng': 78.4230681}}},
#    'place_id': 'ChIJ9XhRlHK9yzsR0oFV3LYM8SQ',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}],
#  ' Aparna County, Matrusri Nagar, Miyapur, NH 9, Hyderabad': [{'address_components': [{'long_name': 'Aparna County Access Road',
#      'short_name': 'Aparna County Access Rd',
#      'types': ['route']},
#     {'long_name': 'Mathrusree Nagar',
#      'short_name': 'Mathrusree Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Hafeezpet',
#      'short_name': 'Hafeezpet',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500049', 'short_name': '500049', 'types': ['postal_code']}],
#    'formatted_address': 'Aparna County Access Rd, Mathrusree Nagar, Hafeezpet, Hyderabad, Telangana 500049, India',
#    'geometry': {'location': {'lat': 17.4901609, 'lng': 78.3643433},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4915098802915,
#       'lng': 78.36569228029151},
#      'southwest': {'lat': 17.4888119197085, 'lng': 78.36299431970849}}},
#    'place_id': 'ChIJY-PI0j-SyzsRZwR4y9yk_EE',
#    'plus_code': {'compound_code': 'F9R7+3P Hafeezpet, Hyderabad, Telangana, India',
#     'global_code': '7J9WF9R7+3P'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Adarsh Nagar Colony-Nagole, Hyderabad': [{'address_components': [{'long_name': 'Adarsh Nagar Colony',
#      'short_name': 'Adarsh Nagar Colony',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Nagole',
#      'short_name': 'Nagole',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500068', 'short_name': '500068', 'types': ['postal_code']}],
#    'formatted_address': 'Adarsh Nagar Colony, Nagole, Hyderabad, Telangana 500068, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.3764611, 'lng': 78.5612953},
#      'southwest': {'lat': 17.367929, 'lng': 78.55720099999999}},
#     'location': {'lat': 17.3718348, 'lng': 78.5596971},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.3764611, 'lng': 78.5612953},
#      'southwest': {'lat': 17.367929, 'lng': 78.55720099999999}}},
#    'place_id': 'ChIJ02g2iM6YyzsRRmKvZnEUdXY',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}],
#  ' Telecom Nagar, Gachibowli, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': 'Nehru Outer Ring Road',
#      'short_name': 'Nehru Outer Ring Rd',
#      'types': ['route']},
#     {'long_name': 'Telecom Nagar',
#      'short_name': 'Telecom Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Gachibowli',
#      'short_name': 'Gachibowli',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Nehru Outer Ring Rd, Telecom Nagar, Gachibowli, Hyderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4385862, 'lng': 78.3637078},
#      'southwest': {'lat': 17.4295076, 'lng': 78.3590464}},
#     'location': {'lat': 17.4340424, 'lng': 78.360768},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4385862, 'lng': 78.3637078},
#      'southwest': {'lat': 17.4295076, 'lng': 78.3590464}}},
#    'place_id': 'EktOZWhydSBPdXRlciBSaW5nIFJkLCBUZWxlY29tIE5hZ2FyLCBHYWNoaWJvd2xpLCBIeWRlcmFiYWQsIFRlbGFuZ2FuYSwgSW5kaWEiLiosChQKEgnXu6E9TXXLOxH8vLSE8JTABhIUChIJX6KoDfKTyzsREOEocxDurkQ',
#    'types': ['route']}],
#  ' Mahendra Hills, Secunderabad, Hyderabad': [{'address_components': [{'long_name': 'Mahendra Hills',
#      'short_name': 'Mahendra Hills',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Malkajgiri',
#      'short_name': 'Malkajgiri',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Secunderabad',
#      'short_name': 'SC',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Mahendra Hills, Malkajgiri, Secunderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4611171, 'lng': 78.526656},
#      'southwest': {'lat': 17.444017, 'lng': 78.5115229}},
#     'location': {'lat': 17.4546797, 'lng': 78.51922979999999},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.4611171, 'lng': 78.526656},
#      'southwest': {'lat': 17.444017, 'lng': 78.5115229}}},
#    'place_id': 'ChIJoWeVgkqayzsRhbmGMnQ2xQw',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}],
#  ' Vertex Panache, Gachibowli, Outer Ring Road, Hyderabad': [{'address_components': [{'long_name': 'Post & Village',
#      'short_name': 'Post & Village',
#      'types': ['establishment', 'point_of_interest']},
#     {'long_name': 'Rajendranagar mandal',
#      'short_name': 'Rajendranagar mandal',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Hyderabad',
#      'short_name': 'Hyderabad',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '500075', 'short_name': '500075', 'types': ['postal_code']}],
#    'formatted_address': 'Survey No. 180 to 183 and 184 part, Near Akshya Patra, Kokapet Ranga Reddy District Narsingi, Post & Village, Rajendranagar mandal, Hyderabad, Telangana 500075, India',
#    'geometry': {'location': {'lat': 17.3994734, 'lng': 78.34250569999999},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 17.4008223802915,
#       'lng': 78.3438546802915},
#      'southwest': {'lat': 17.3981244197085, 'lng': 78.34115671970848}}},
#    'place_id': 'ChIJaVVVhVuRyzsRIf1x1aLvoZc',
#    'plus_code': {'compound_code': '98XV+Q2 Rajendranagar mandal, Hyderabad, Telangana, India',
#     'global_code': '7J9W98XV+Q2'},
#    'types': ['establishment', 'point_of_interest']}],
#  ' Hema Nagar, Secunderabad, Hyderabad': [{'address_components': [{'long_name': 'Hema Nagar',
#      'short_name': 'Hema Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Boduppal',
#      'short_name': 'Boduppal',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Secunderabad',
#      'short_name': 'SC',
#      'types': ['locality', 'political']},
#     {'long_name': 'Ranga Reddy',
#      'short_name': 'R.R. District',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Telangana',
#      'short_name': 'Telangana',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Hema Nagar, Boduppal, Secunderabad, Telangana, India',
#    'geometry': {'bounds': {'northeast': {'lat': 17.4238139, 'lng': 78.571224},
#      'southwest': {'lat': 17.413369, 'lng': 78.56448309999999}},
#     'location': {'lat': 17.4196115, 'lng': 78.5675047},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 17.4238139, 'lng': 78.571224},
#      'southwest': {'lat': 17.413369, 'lng': 78.56448309999999}}},
#    'place_id': 'ChIJT76n5rKeyzsRZC4eVqLwKKs',
#    'types': ['political', 'sublocality', 'sublocality_level_2']}]}

# %%
df['gmaps_info'] = df['address'].apply(lambda x: unique_geocodes[x])

# %%
def extract_coords(geo):
    try:
        geo = geo[-1] # drop generalized extra results
        return geo['geometry']['location']['lat'], geo['geometry']['location']['lng']
    except:
        return np.nan, np.nan

# %%
df['coord'] = df['gmaps_info'].apply(extract_coords)
df['latitude'].fillna(df['coord'].apply(lambda x: x[0]), inplace=True)
df['longitude'].fillna(df['coord'].apply(lambda x: x[1]), inplace=True)
df.head()
# Out:
#       price                                              title  \
# 0  ₹ 18,000     3 BHK House for rent in Gudimalkapur 1400 sqft
# 1  ₹ 20,000       3 BHK Villa for rent in Shamshabad 1500 sqft
# 2   ₹ 5,800  1 BHK Apartment for rent in Vinayak Nagar II-H...
# 3  ₹ 14,000  2 BHK Apartment for rent in Kukatpally, NH 9 1...
# 4  ₹ 20,000     3 BHK Apartment for rent in Dellapur 1560 sqft
#
#        furnishing tenants preferred bathroom  availability  longitude  \
# 0     Unfurnished  Bachelors/Family        2   Immediately  78.437402
# 1     Unfurnished         Bachelors        3  From Mar '20  17.270166
# 2     Unfurnished            Family        1   Immediately  78.598729
# 3  Semi-Furnished  Bachelors/Family        2   Immediately  78.399146
# 4  Semi-Furnished  Bachelors/Family        2   Immediately  78.286481
#
#     latitude balcony              floor facing overlooking car parking  \
# 0  17.378782     NaN                NaN    NaN         NaN         NaN
# 1  78.393593       3                NaN    NaN         NaN         NaN
# 2  17.331128       1   1 out of 1 Floor   East   Main Road         NaN
# 3  17.494868     NaN  2 out of 5 Floors    NaN         NaN         NaN
# 4  17.463172     NaN  5 out of 5 Floors    NaN         NaN         NaN
#
#   owner resides                                   address  \
# 0           NaN                   Gudimalkapur, Hyderabad
# 1           NaN                     Shamshabad, Hyderabad
# 2           NaN   Vinayak Nagar II-Hayathnagar, Hyderabad
# 3           NaN               Kukatpally, NH 9, Hyderabad
# 4           NaN                       Dellapur, Hyderabad
#
#                                           gmaps_info                     coord
# 0  [{'address_components': [{'long_name': 'Gudima...  (17.3787821, 78.4374024)
# 1  [{'address_components': [{'long_name': 'Shamsh...   (17.2619301, 78.387971)
# 2  [{'address_components': [{'long_name': 'Vinaya...  (17.3311276, 78.5987291)
# 3  [{'address_components': [{'long_name': 'Nation...  (17.4948682, 78.3991456)
# 4  [{'address_components': [{'long_name': 'Tellap...   (17.463172, 78.2864815)

# %% [markdown]
# ### Export

# %%
df.to_csv('geocoded.csv', index=False)
